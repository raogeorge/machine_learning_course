# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def sigmoid(x):
    """Sigmoid activation function"""
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    """Derivative of sigmoid function"""
    return sigmoid(x) * (1 - sigmoid(x))

def initialize_weights(input_size, hidden_sizes, output_size):
    """Initialize weights and biases with standard Gaussian distribution"""
    weights = []
    biases = []
    
    # Input to first hidden layer
    weights.append(np.random.randn(hidden_sizes[0], input_size))
    biases.append(np.zeros((hidden_sizes[0], 1)))
    
    # Between hidden layers
    for i in range(1, len(hidden_sizes)):
        weights.append(np.random.randn(hidden_sizes[i], hidden_sizes[i-1]))
        biases.append(np.zeros((hidden_sizes[i], 1)))
    
    # Last hidden to output layer
    weights.append(np.random.randn(output_size, hidden_sizes[-1]))
    biases.append(np.zeros((output_size, 1)))
    
    return weights, biases

def forward_propagation(X, weights, biases):
    """Forward pass through the network"""
    activations = [X]
    zs = []
    
    for W, b in zip(weights, biases):
        z = np.dot(W, activations[-1]) + b
        a = sigmoid(z)
        zs.append(z)
        activations.append(a)
    
    return activations, zs

def backward_propagation(X, y, weights, biases, activations, zs):
    """Compute gradients using backpropagation"""
    gradients_w = [np.zeros_like(W) for W in weights]
    gradients_b = [np.zeros_like(b) for b in biases]
    
    # Output layer error
    delta = activations[-1] - y.reshape(-1, 1)
    
    # Gradient for last layer
    gradients_w[-1] = np.dot(delta, activations[-2].T)
    gradients_b[-1] = delta
    
    # Backpropagate through hidden layers
    for l in range(len(weights) - 2, -1, -1):
        delta = np.dot(weights[l + 1].T, delta) * sigmoid_derivative(zs[l])
        gradients_w[l] = np.dot(delta, activations[l].T)
        gradients_b[l] = delta
    
    return gradients_w, gradients_b

def load_data(train_path, test_path):
    """Load and prepare the bank-note dataset"""
    train_data = pd.read_csv(train_path, header=None)
    test_data = pd.read_csv(test_path, header=None)
    
    X_train = train_data.iloc[:, :-1].values.T
    y_train = train_data.iloc[:, -1].values
    X_test = test_data.iloc[:, :-1].values.T
    y_test = test_data.iloc[:, -1].values
    
    return X_train, y_train, X_test, y_test

def shuffle_data(X, y):
    """Shuffle the data while keeping features and labels aligned"""
    indices = np.random.permutation(X.shape[1])
    return X[:, indices], y[indices]

def learning_rate_schedule(gamma0, d, t):
    """Implement the learning rate schedule: γt = γ0/(1 + (γ0/d)t)"""
    return gamma0 / (1 + (gamma0/d) * t)

def compute_loss(X, y, weights, biases):
    """Compute binary cross entropy loss"""
    activations, _ = forward_propagation(X, weights, biases)
    predictions = activations[-1]
    epsilon = 1e-15  # prevent log(0)
    return -np.mean(y * np.log(predictions + epsilon) + 
                   (1 - y) * np.log(1 - predictions + epsilon))

def compute_accuracy(X, y, weights, biases):
    """Compute classification accuracy"""
    activations, _ = forward_propagation(X, weights, biases)
    predictions = (activations[-1] > 0.5).reshape(-1)
    return np.mean(predictions == y)

def train_network(X_train, y_train, X_test, y_test, hidden_width, gamma0, d, max_updates=1000):
    """Train neural network using SGD with specified learning rate schedule"""
    input_size = X_train.shape[0]
    hidden_sizes = [hidden_width, hidden_width]  # equal width layers
    output_size = 1
    
    weights, biases = initialize_weights(input_size, hidden_sizes, output_size)
    
    train_losses = []
    train_errors = []
    test_errors = []
    updates = 0
    
    X_shuffled, y_shuffled = shuffle_data(X_train, y_train)
    i = 0
    
    while updates < max_updates:
        # Reshuffle if we've used all examples
        if i >= X_train.shape[1]:
            X_shuffled, y_shuffled = shuffle_data(X_train, y_train)
            i = 0
            
        # Get current learning rate
        lr = learning_rate_schedule(gamma0, d, updates)
        
        # Get single training example
        X = X_shuffled[:, [i]]
        y = y_shuffled[[i]]
        
        # Forward and backward passes
        activations, zs = forward_propagation(X, weights, biases)
        gradients_w, gradients_b = backward_propagation(
            X, y, weights, biases, activations, zs)
        
        # Update weights and biases
        for j in range(len(weights)):
            weights[j] -= lr * gradients_w[j]
            biases[j] -= lr * gradients_b[j]
        
        # Track metrics (every 10 updates to reduce computation)
        if updates % 10 == 0:
            train_loss = compute_loss(X_train, y_train, weights, biases)
            train_acc = compute_accuracy(X_train, y_train, weights, biases)
            test_acc = compute_accuracy(X_test, y_test, weights, biases)
            
            train_losses.append(train_loss)
            train_errors.append(1 - train_acc)
            test_errors.append(1 - test_acc)
            
            print(f"Updates: {updates}, Loss: {train_loss:.4f}, "
                  f"Train Error: {1-train_acc:.4f}, Test Error: {1-test_acc:.4f}")
        
        updates += 1
        i += 1
    
    return train_losses, train_errors, test_errors, weights, biases

if __name__ == "__main__":
    # Load data
    train_path = "train.csv"
    test_path = "test.csv"
    X_train, y_train, X_test, y_test = load_data(train_path, test_path)
    
    np.random.seed(2)
    
    # Network widths to test
    widths = [5, 10, 25, 50, 100]
    
    # Store results
    results = {}
    
    for width in widths:
        print(f"\nTraining network with width {width}")
        
        train_losses, train_errors, test_errors, _, _ = train_network(
            X_train, y_train, X_test, y_test,
            hidden_width=width,
            gamma0=0.1,  # Need to tune this
            d=100,       # Need to tune this
            max_updates=1000
        )
        
        # Plot learning curves
        plt.figure(figsize=(15, 5))
        
        # Plot loss vs updates
        plt.subplot(1, 2, 1)
        plt.plot(range(0, len(train_losses)*10, 10), train_losses)
        plt.title(f'Training Loss vs Updates (Width={width})')
        plt.xlabel('Number of Updates')
        plt.ylabel('Binary Cross Entropy Loss')
        
        # Plot error rates vs updates
        plt.subplot(1, 2, 2)
        plt.plot(range(0, len(train_errors)*10, 10), train_errors, label='Train Error')
        plt.plot(range(0, len(test_errors)*10, 10), test_errors, label='Test Error')
        plt.title(f'Error Rates vs Updates (Width={width})')
        plt.xlabel('Number of Updates')
        plt.ylabel('Error Rate')
        plt.legend()
        
        plt.tight_layout()
        plt.show()
        
        print(f"\nFinal Results for Width {width}:")
        print(f"Final Training Error: {train_errors[-1]:.4f}")
        print(f"Final Test Error: {test_errors[-1]:.4f}")
# Out:
# Training network with width 5
# Updates: 0, Loss: 0.7185, Train Error: 0.4461, Test Error: 0.4420
# Updates: 10, Loss: 0.7070, Train Error: 0.4461, Test Error: 0.4420
# Updates: 20, Loss: 0.7045, Train Error: 0.4461, Test Error: 0.4420
# Updates: 30, Loss: 0.7208, Train Error: 0.4461, Test Error: 0.4420
# Updates: 40, Loss: 0.7039, Train Error: 0.4461, Test Error: 0.4420
# Updates: 50, Loss: 0.6991, Train Error: 0.5057, Test Error: 0.5060
# Updates: 60, Loss: 0.6975, Train Error: 0.5103, Test Error: 0.4960
# Updates: 70, Loss: 0.6885, Train Error: 0.4461, Test Error: 0.4420
# Updates: 80, Loss: 0.6961, Train Error: 0.5057, Test Error: 0.5040
# Updates: 90, Loss: 0.6913, Train Error: 0.4782, Test Error: 0.4860
# Updates: 100, Loss: 0.7021, Train Error: 0.5700, Test Error: 0.5700
# Updates: 110, Loss: 0.7369, Train Error: 0.5539, Test Error: 0.5580
# Updates: 120, Loss: 0.7043, Train Error: 0.5619, Test Error: 0.5620
# Updates: 130, Loss: 0.6886, Train Error: 0.5814, Test Error: 0.5700
# Updates: 140, Loss: 0.7217, Train Error: 0.5539, Test Error: 0.5580
# Updates: 150, Loss: 0.6797, Train Error: 0.4358, Test Error: 0.4460
# Updates: 160, Loss: 0.6757, Train Error: 0.4461, Test Error: 0.4420
# Updates: 170, Loss: 0.6594, Train Error: 0.3280, Test Error: 0.3220
# Updates: 180, Loss: 0.6600, Train Error: 0.4461, Test Error: 0.4420
# Updates: 190, Loss: 0.6608, Train Error: 0.4461, Test Error: 0.4420
# Updates: 200, Loss: 0.6509, Train Error: 0.2764, Test Error: 0.2520
# Updates: 210, Loss: 0.6622, Train Error: 0.3876, Test Error: 0.4040
# Updates: 220, Loss: 0.6439, Train Error: 0.2443, Test Error: 0.2320
# Updates: 230, Loss: 0.6498, Train Error: 0.2374, Test Error: 0.2540
# Updates: 240, Loss: 0.6343, Train Error: 0.3234, Test Error: 0.3040
# Updates: 250, Loss: 0.6296, Train Error: 0.3039, Test Error: 0.3000
# Updates: 260, Loss: 0.6341, Train Error: 0.2076, Test Error: 0.2180
# Updates: 270, Loss: 0.6426, Train Error: 0.3394, Test Error: 0.3380
# Updates: 280, Loss: 0.6243, Train Error: 0.1995, Test Error: 0.2160
# Updates: 290, Loss: 0.6240, Train Error: 0.2064, Test Error: 0.2200
# Updates: 300, Loss: 0.6214, Train Error: 0.1927, Test Error: 0.2060
# Updates: 310, Loss: 0.6192, Train Error: 0.1961, Test Error: 0.2100
# Updates: 320, Loss: 0.6068, Train Error: 0.1778, Test Error: 0.1880
# Updates: 330, Loss: 0.5960, Train Error: 0.2213, Test Error: 0.2040
# Updates: 340, Loss: 0.5915, Train Error: 0.2144, Test Error: 0.2000
# Updates: 350, Loss: 0.5913, Train Error: 0.3062, Test Error: 0.2880
# Updates: 360, Loss: 0.5980, Train Error: 0.3360, Test Error: 0.3100
# Updates: 370, Loss: 0.5823, Train Error: 0.3005, Test Error: 0.2760
# Updates: 380, Loss: 0.5731, Train Error: 0.2592, Test Error: 0.2600
# Updates: 390, Loss: 0.5761, Train Error: 0.3005, Test Error: 0.2740
# Updates: 400, Loss: 0.5620, Train Error: 0.1697, Test Error: 0.1700
# Updates: 410, Loss: 0.5521, Train Error: 0.1697, Test Error: 0.1680
# Updates: 420, Loss: 0.5497, Train Error: 0.2041, Test Error: 0.1800
# Updates: 430, Loss: 0.5562, Train Error: 0.2821, Test Error: 0.2720
# Updates: 440, Loss: 0.5397, Train Error: 0.2018, Test Error: 0.1800
# Updates: 450, Loss: 0.5333, Train Error: 0.1835, Test Error: 0.1700
# Updates: 460, Loss: 0.5300, Train Error: 0.1846, Test Error: 0.1740
# Updates: 470, Loss: 0.5282, Train Error: 0.1456, Test Error: 0.1700
# Updates: 480, Loss: 0.5106, Train Error: 0.1307, Test Error: 0.1380
# Updates: 490, Loss: 0.5175, Train Error: 0.1468, Test Error: 0.1740
# Updates: 500, Loss: 0.4968, Train Error: 0.1273, Test Error: 0.1360
# Updates: 510, Loss: 0.4801, Train Error: 0.1067, Test Error: 0.1220
# Updates: 520, Loss: 0.4946, Train Error: 0.2122, Test Error: 0.2080
# Updates: 530, Loss: 0.4777, Train Error: 0.1789, Test Error: 0.1740
# Updates: 540, Loss: 0.4689, Train Error: 0.1743, Test Error: 0.1580
# Updates: 550, Loss: 0.4455, Train Error: 0.0952, Test Error: 0.1140
# Updates: 560, Loss: 0.4505, Train Error: 0.1514, Test Error: 0.1420
# Updates: 570, Loss: 0.4382, Train Error: 0.1227, Test Error: 0.1180
# Updates: 580, Loss: 0.4297, Train Error: 0.1112, Test Error: 0.1080
# Updates: 590, Loss: 0.4252, Train Error: 0.1101, Test Error: 0.1040
# Updates: 600, Loss: 0.4165, Train Error: 0.0963, Test Error: 0.0940
# Updates: 610, Loss: 0.4162, Train Error: 0.1032, Test Error: 0.1040
# Updates: 620, Loss: 0.4209, Train Error: 0.1388, Test Error: 0.1360
# Updates: 630, Loss: 0.4150, Train Error: 0.1376, Test Error: 0.1340
# Updates: 640, Loss: 0.3806, Train Error: 0.0780, Test Error: 0.0880
# Updates: 650, Loss: 0.3760, Train Error: 0.0745, Test Error: 0.0900
# Updates: 660, Loss: 0.3673, Train Error: 0.0688, Test Error: 0.0680
# Updates: 670, Loss: 0.3618, Train Error: 0.0665, Test Error: 0.0640
# Updates: 680, Loss: 0.3492, Train Error: 0.0654, Test Error: 0.0720
# Updates: 690, Loss: 0.3432, Train Error: 0.0654, Test Error: 0.0740
# Updates: 700, Loss: 0.3420, Train Error: 0.0722, Test Error: 0.0720
# Updates: 710, Loss: 0.3308, Train Error: 0.0654, Test Error: 0.0720
# Updates: 720, Loss: 0.3282, Train Error: 0.0631, Test Error: 0.0760
# Updates: 730, Loss: 0.3199, Train Error: 0.0528, Test Error: 0.0560
# Updates: 740, Loss: 0.3149, Train Error: 0.0608, Test Error: 0.0760
# Updates: 750, Loss: 0.3083, Train Error: 0.0654, Test Error: 0.0660
# Updates: 760, Loss: 0.3011, Train Error: 0.0631, Test Error: 0.0640
# Updates: 770, Loss: 0.2991, Train Error: 0.0539, Test Error: 0.0540
# Updates: 780, Loss: 0.2945, Train Error: 0.0550, Test Error: 0.0580
# Updates: 790, Loss: 0.2901, Train Error: 0.0550, Test Error: 0.0740
# Updates: 800, Loss: 0.2829, Train Error: 0.0528, Test Error: 0.0600
# Updates: 810, Loss: 0.2791, Train Error: 0.0505, Test Error: 0.0680
# Updates: 820, Loss: 0.2651, Train Error: 0.0550, Test Error: 0.0500
# Updates: 830, Loss: 0.2582, Train Error: 0.0459, Test Error: 0.0400
# Updates: 840, Loss: 0.2540, Train Error: 0.0482, Test Error: 0.0400
# Updates: 850, Loss: 0.2534, Train Error: 0.0470, Test Error: 0.0400
# Updates: 860, Loss: 0.2533, Train Error: 0.0459, Test Error: 0.0340
# Updates: 870, Loss: 0.2391, Train Error: 0.0493, Test Error: 0.0440
# Updates: 880, Loss: 0.2398, Train Error: 0.0413, Test Error: 0.0320
# Updates: 890, Loss: 0.2300, Train Error: 0.0447, Test Error: 0.0380
# Updates: 900, Loss: 0.2231, Train Error: 0.0459, Test Error: 0.0380
# Updates: 910, Loss: 0.2167, Train Error: 0.0459, Test Error: 0.0420
# Updates: 920, Loss: 0.2131, Train Error: 0.0470, Test Error: 0.0420
# Updates: 930, Loss: 0.2082, Train Error: 0.0459, Test Error: 0.0400
# Updates: 940, Loss: 0.2036, Train Error: 0.0436, Test Error: 0.0380
# Updates: 950, Loss: 0.2003, Train Error: 0.0413, Test Error: 0.0440
# Updates: 960, Loss: 0.1969, Train Error: 0.0436, Test Error: 0.0440
# Updates: 970, Loss: 0.1957, Train Error: 0.0424, Test Error: 0.0460
# Updates: 980, Loss: 0.1937, Train Error: 0.0436, Test Error: 0.0480
# Updates: 990, Loss: 0.1846, Train Error: 0.0424, Test Error: 0.0420
# Final Results for Width 5:
# Final Training Error: 0.0424
# Final Test Error: 0.0420
#
# Training network with width 10
# Updates: 0, Loss: 1.3359, Train Error: 0.5665, Test Error: 0.5560
# Updates: 10, Loss: 0.7276, Train Error: 0.3784, Test Error: 0.4000
# Updates: 20, Loss: 0.6052, Train Error: 0.2420, Test Error: 0.2480
# Updates: 30, Loss: 0.6435, Train Error: 0.3727, Test Error: 0.3780
# Updates: 40, Loss: 0.5443, Train Error: 0.3337, Test Error: 0.3440
# Updates: 50, Loss: 0.4456, Train Error: 0.1778, Test Error: 0.1800
# Updates: 60, Loss: 0.4074, Train Error: 0.1216, Test Error: 0.1260
# Updates: 70, Loss: 0.4171, Train Error: 0.1468, Test Error: 0.1440
# Updates: 80, Loss: 0.3624, Train Error: 0.1158, Test Error: 0.1220
# Updates: 90, Loss: 0.3219, Train Error: 0.0894, Test Error: 0.1060
# Updates: 100, Loss: 0.3136, Train Error: 0.0734, Test Error: 0.0800
# Updates: 110, Loss: 0.3032, Train Error: 0.0436, Test Error: 0.0520
# Updates: 120, Loss: 0.2592, Train Error: 0.0436, Test Error: 0.0580
# Updates: 130, Loss: 0.2543, Train Error: 0.0333, Test Error: 0.0480
# Updates: 140, Loss: 0.2363, Train Error: 0.0470, Test Error: 0.0700
# Updates: 150, Loss: 0.2195, Train Error: 0.0275, Test Error: 0.0520
# Updates: 160, Loss: 0.2647, Train Error: 0.0470, Test Error: 0.0560
# Updates: 170, Loss: 0.2282, Train Error: 0.0126, Test Error: 0.0160
# Updates: 180, Loss: 0.2207, Train Error: 0.0138, Test Error: 0.0200
# Updates: 190, Loss: 0.1946, Train Error: 0.0149, Test Error: 0.0100
# Updates: 200, Loss: 0.2027, Train Error: 0.0092, Test Error: 0.0120
# Updates: 210, Loss: 0.1716, Train Error: 0.0161, Test Error: 0.0140
# Updates: 220, Loss: 0.1633, Train Error: 0.0115, Test Error: 0.0060
# Updates: 230, Loss: 0.1542, Train Error: 0.0138, Test Error: 0.0160
# Updates: 240, Loss: 0.1459, Train Error: 0.0172, Test Error: 0.0180
# Updates: 250, Loss: 0.1456, Train Error: 0.0172, Test Error: 0.0220
# Updates: 260, Loss: 0.1382, Train Error: 0.0161, Test Error: 0.0200
# Updates: 270, Loss: 0.1604, Train Error: 0.0436, Test Error: 0.0600
# Updates: 280, Loss: 0.1603, Train Error: 0.0493, Test Error: 0.0660
# Updates: 290, Loss: 0.1401, Train Error: 0.0321, Test Error: 0.0440
# Updates: 300, Loss: 0.1356, Train Error: 0.0321, Test Error: 0.0420
# Updates: 310, Loss: 0.1321, Train Error: 0.0092, Test Error: 0.0080
# Updates: 320, Loss: 0.1268, Train Error: 0.0195, Test Error: 0.0120
# Updates: 330, Loss: 0.1144, Train Error: 0.0138, Test Error: 0.0120
# Updates: 340, Loss: 0.1168, Train Error: 0.0275, Test Error: 0.0320
# Updates: 350, Loss: 0.1140, Train Error: 0.0126, Test Error: 0.0080
# Updates: 360, Loss: 0.1114, Train Error: 0.0183, Test Error: 0.0140
# Updates: 370, Loss: 0.1028, Train Error: 0.0092, Test Error: 0.0100
# Updates: 380, Loss: 0.1034, Train Error: 0.0126, Test Error: 0.0140
# Updates: 390, Loss: 0.0946, Train Error: 0.0138, Test Error: 0.0120
# Updates: 400, Loss: 0.0916, Train Error: 0.0161, Test Error: 0.0140
# Updates: 410, Loss: 0.1014, Train Error: 0.0229, Test Error: 0.0240
# Updates: 420, Loss: 0.1058, Train Error: 0.0241, Test Error: 0.0320
# Updates: 430, Loss: 0.0959, Train Error: 0.0183, Test Error: 0.0240
# Updates: 440, Loss: 0.2623, Train Error: 0.1032, Test Error: 0.1160
# Updates: 450, Loss: 0.2476, Train Error: 0.0998, Test Error: 0.1120
# Updates: 460, Loss: 0.1698, Train Error: 0.0493, Test Error: 0.0660
# Updates: 470, Loss: 0.1690, Train Error: 0.0470, Test Error: 0.0660
# Updates: 480, Loss: 0.1614, Train Error: 0.0493, Test Error: 0.0680
# Updates: 490, Loss: 0.1260, Train Error: 0.0333, Test Error: 0.0280
# Updates: 500, Loss: 0.1247, Train Error: 0.0344, Test Error: 0.0320
# Updates: 510, Loss: 0.1233, Train Error: 0.0356, Test Error: 0.0320
# Updates: 520, Loss: 0.1203, Train Error: 0.0356, Test Error: 0.0360
# Updates: 530, Loss: 0.1169, Train Error: 0.0333, Test Error: 0.0340
# Updates: 540, Loss: 0.1095, Train Error: 0.0298, Test Error: 0.0260
# Updates: 550, Loss: 0.1008, Train Error: 0.0275, Test Error: 0.0240
# Updates: 560, Loss: 0.1001, Train Error: 0.0287, Test Error: 0.0240
# Updates: 570, Loss: 0.0982, Train Error: 0.0287, Test Error: 0.0240
# Updates: 580, Loss: 0.1010, Train Error: 0.0264, Test Error: 0.0220
# Updates: 590, Loss: 0.0969, Train Error: 0.0252, Test Error: 0.0220
# Updates: 600, Loss: 0.0943, Train Error: 0.0252, Test Error: 0.0220
# Updates: 610, Loss: 0.0922, Train Error: 0.0252, Test Error: 0.0220
# Updates: 620, Loss: 0.0863, Train Error: 0.0183, Test Error: 0.0160
# Updates: 630, Loss: 0.0905, Train Error: 0.0229, Test Error: 0.0220
# Updates: 640, Loss: 0.0952, Train Error: 0.0264, Test Error: 0.0280
# Updates: 650, Loss: 0.0810, Train Error: 0.0264, Test Error: 0.0240
# Updates: 660, Loss: 0.0803, Train Error: 0.0264, Test Error: 0.0240
# Updates: 670, Loss: 0.0798, Train Error: 0.0206, Test Error: 0.0220
# Updates: 680, Loss: 0.0902, Train Error: 0.0252, Test Error: 0.0240
# Updates: 690, Loss: 0.0890, Train Error: 0.0241, Test Error: 0.0200
# Updates: 700, Loss: 0.0772, Train Error: 0.0183, Test Error: 0.0200
# Updates: 710, Loss: 0.0760, Train Error: 0.0183, Test Error: 0.0200
# Updates: 720, Loss: 0.0725, Train Error: 0.0161, Test Error: 0.0140
# Updates: 730, Loss: 0.0698, Train Error: 0.0161, Test Error: 0.0160
# Updates: 740, Loss: 0.0639, Train Error: 0.0115, Test Error: 0.0100
# Updates: 750, Loss: 0.0536, Train Error: 0.0034, Test Error: 0.0020
# Updates: 760, Loss: 0.0547, Train Error: 0.0023, Test Error: 0.0020
# Updates: 770, Loss: 0.0543, Train Error: 0.0023, Test Error: 0.0040
# Updates: 780, Loss: 0.0523, Train Error: 0.0023, Test Error: 0.0040
# Updates: 790, Loss: 0.0522, Train Error: 0.0034, Test Error: 0.0040
# Updates: 800, Loss: 0.0516, Train Error: 0.0023, Test Error: 0.0040
# Updates: 810, Loss: 0.0509, Train Error: 0.0046, Test Error: 0.0040
# Updates: 820, Loss: 0.0502, Train Error: 0.0046, Test Error: 0.0040
# Updates: 830, Loss: 0.0500, Train Error: 0.0046, Test Error: 0.0040
# Updates: 840, Loss: 0.0506, Train Error: 0.0057, Test Error: 0.0080
# Updates: 850, Loss: 0.0507, Train Error: 0.0057, Test Error: 0.0080
# Updates: 860, Loss: 0.0464, Train Error: 0.0023, Test Error: 0.0020
# Updates: 870, Loss: 0.0462, Train Error: 0.0023, Test Error: 0.0020
# Updates: 880, Loss: 0.0462, Train Error: 0.0034, Test Error: 0.0020
# Updates: 890, Loss: 0.0458, Train Error: 0.0034, Test Error: 0.0020
# Updates: 900, Loss: 0.0451, Train Error: 0.0023, Test Error: 0.0020
# Updates: 910, Loss: 0.0447, Train Error: 0.0034, Test Error: 0.0020
# Updates: 920, Loss: 0.0445, Train Error: 0.0034, Test Error: 0.0020
# Updates: 930, Loss: 0.0444, Train Error: 0.0011, Test Error: 0.0000
# Updates: 940, Loss: 0.0435, Train Error: 0.0023, Test Error: 0.0000
# Updates: 950, Loss: 0.0486, Train Error: 0.0046, Test Error: 0.0040
# Updates: 960, Loss: 0.0477, Train Error: 0.0046, Test Error: 0.0040
# Updates: 970, Loss: 0.0458, Train Error: 0.0000, Test Error: 0.0000
# Updates: 980, Loss: 0.0453, Train Error: 0.0000, Test Error: 0.0000
# Updates: 990, Loss: 0.0422, Train Error: 0.0000, Test Error: 0.0000
# Final Results for Width 10:
# Final Training Error: 0.0000
# Final Test Error: 0.0000
#
# Training network with width 25
# Updates: 0, Loss: 0.8994, Train Error: 0.5413, Test Error: 0.5320
# Updates: 10, Loss: 0.6181, Train Error: 0.3211, Test Error: 0.3060
# Updates: 20, Loss: 0.5604, Train Error: 0.2878, Test Error: 0.2800
# Updates: 30, Loss: 0.6944, Train Error: 0.4323, Test Error: 0.4660
# Updates: 40, Loss: 0.3995, Train Error: 0.1445, Test Error: 0.1360
# Updates: 50, Loss: 0.3412, Train Error: 0.1376, Test Error: 0.1320
# Updates: 60, Loss: 0.3633, Train Error: 0.0849, Test Error: 0.0980
# Updates: 70, Loss: 0.3215, Train Error: 0.1628, Test Error: 0.1500
# Updates: 80, Loss: 0.2832, Train Error: 0.1307, Test Error: 0.1300
# Updates: 90, Loss: 0.2295, Train Error: 0.0482, Test Error: 0.0660
# Updates: 100, Loss: 0.2042, Train Error: 0.0264, Test Error: 0.0460
# Updates: 110, Loss: 0.1895, Train Error: 0.0310, Test Error: 0.0440
# Updates: 120, Loss: 0.1867, Train Error: 0.0264, Test Error: 0.0400
# Updates: 130, Loss: 0.1790, Train Error: 0.0378, Test Error: 0.0580
# Updates: 140, Loss: 0.1798, Train Error: 0.0493, Test Error: 0.0700
# Updates: 150, Loss: 0.1627, Train Error: 0.0310, Test Error: 0.0440
# Updates: 160, Loss: 0.1534, Train Error: 0.0344, Test Error: 0.0480
# Updates: 170, Loss: 0.1598, Train Error: 0.0195, Test Error: 0.0320
# Updates: 180, Loss: 0.1289, Train Error: 0.0149, Test Error: 0.0140
# Updates: 190, Loss: 0.1462, Train Error: 0.0275, Test Error: 0.0360
# Updates: 200, Loss: 0.1526, Train Error: 0.0390, Test Error: 0.0480
# Updates: 210, Loss: 0.1459, Train Error: 0.0378, Test Error: 0.0440
# Updates: 220, Loss: 0.1180, Train Error: 0.0149, Test Error: 0.0160
# Updates: 230, Loss: 0.1158, Train Error: 0.0138, Test Error: 0.0180
# Updates: 240, Loss: 0.1006, Train Error: 0.0115, Test Error: 0.0100
# Updates: 250, Loss: 0.0960, Train Error: 0.0115, Test Error: 0.0120
# Updates: 260, Loss: 0.0941, Train Error: 0.0103, Test Error: 0.0120
# Updates: 270, Loss: 0.0938, Train Error: 0.0092, Test Error: 0.0160
# Updates: 280, Loss: 0.0941, Train Error: 0.0126, Test Error: 0.0160
# Updates: 290, Loss: 0.0891, Train Error: 0.0092, Test Error: 0.0120
# Updates: 300, Loss: 0.0984, Train Error: 0.0138, Test Error: 0.0180
# Updates: 310, Loss: 0.0994, Train Error: 0.0183, Test Error: 0.0220
# Updates: 320, Loss: 0.0762, Train Error: 0.0103, Test Error: 0.0100
# Updates: 330, Loss: 0.0744, Train Error: 0.0103, Test Error: 0.0120
# Updates: 340, Loss: 0.0767, Train Error: 0.0092, Test Error: 0.0060
# Updates: 350, Loss: 0.0708, Train Error: 0.0092, Test Error: 0.0100
# Updates: 360, Loss: 0.0696, Train Error: 0.0103, Test Error: 0.0120
# Updates: 370, Loss: 0.0695, Train Error: 0.0080, Test Error: 0.0080
# Updates: 380, Loss: 0.0686, Train Error: 0.0080, Test Error: 0.0080
# Updates: 390, Loss: 0.0678, Train Error: 0.0080, Test Error: 0.0080
# Updates: 400, Loss: 0.0669, Train Error: 0.0080, Test Error: 0.0080
# Updates: 410, Loss: 0.0675, Train Error: 0.0080, Test Error: 0.0100
# Updates: 420, Loss: 0.0660, Train Error: 0.0080, Test Error: 0.0100
# Updates: 430, Loss: 0.0654, Train Error: 0.0092, Test Error: 0.0100
# Updates: 440, Loss: 0.0657, Train Error: 0.0092, Test Error: 0.0100
# Updates: 450, Loss: 0.0648, Train Error: 0.0080, Test Error: 0.0100
# Updates: 460, Loss: 0.0639, Train Error: 0.0080, Test Error: 0.0100
# Updates: 470, Loss: 0.0721, Train Error: 0.0046, Test Error: 0.0060
# Updates: 480, Loss: 0.0603, Train Error: 0.0069, Test Error: 0.0060
# Updates: 490, Loss: 0.0546, Train Error: 0.0103, Test Error: 0.0120
# Updates: 500, Loss: 0.0725, Train Error: 0.0103, Test Error: 0.0100
# Updates: 510, Loss: 0.0688, Train Error: 0.0103, Test Error: 0.0100
# Updates: 520, Loss: 0.0679, Train Error: 0.0103, Test Error: 0.0100
# Updates: 530, Loss: 0.0700, Train Error: 0.0103, Test Error: 0.0120
# Updates: 540, Loss: 0.0522, Train Error: 0.0115, Test Error: 0.0120
# Updates: 550, Loss: 0.0507, Train Error: 0.0103, Test Error: 0.0120
# Updates: 560, Loss: 0.0515, Train Error: 0.0115, Test Error: 0.0100
# Updates: 570, Loss: 0.0510, Train Error: 0.0115, Test Error: 0.0100
# Updates: 580, Loss: 0.0505, Train Error: 0.0103, Test Error: 0.0100
# Updates: 590, Loss: 0.0499, Train Error: 0.0115, Test Error: 0.0100
# Updates: 600, Loss: 0.0490, Train Error: 0.0115, Test Error: 0.0100
# Updates: 610, Loss: 0.0483, Train Error: 0.0069, Test Error: 0.0060
# Updates: 620, Loss: 0.0448, Train Error: 0.0092, Test Error: 0.0080
# Updates: 630, Loss: 0.0438, Train Error: 0.0103, Test Error: 0.0100
# Updates: 640, Loss: 0.0436, Train Error: 0.0103, Test Error: 0.0100
# Updates: 650, Loss: 0.0430, Train Error: 0.0103, Test Error: 0.0100
# Updates: 660, Loss: 0.0427, Train Error: 0.0103, Test Error: 0.0100
# Updates: 670, Loss: 0.0420, Train Error: 0.0103, Test Error: 0.0120
# Updates: 680, Loss: 0.0528, Train Error: 0.0069, Test Error: 0.0060
# Updates: 690, Loss: 0.0485, Train Error: 0.0069, Test Error: 0.0060
# Updates: 700, Loss: 0.0483, Train Error: 0.0115, Test Error: 0.0180
# Updates: 710, Loss: 0.0475, Train Error: 0.0115, Test Error: 0.0180
# Updates: 720, Loss: 0.0458, Train Error: 0.0126, Test Error: 0.0180
# Updates: 730, Loss: 0.0454, Train Error: 0.0126, Test Error: 0.0180
# Updates: 740, Loss: 0.0530, Train Error: 0.0069, Test Error: 0.0140
# Updates: 750, Loss: 0.0435, Train Error: 0.0069, Test Error: 0.0120
# Updates: 760, Loss: 0.0414, Train Error: 0.0046, Test Error: 0.0100
# Updates: 770, Loss: 0.0391, Train Error: 0.0046, Test Error: 0.0060
# Updates: 780, Loss: 0.0389, Train Error: 0.0092, Test Error: 0.0080
# Updates: 790, Loss: 0.0386, Train Error: 0.0092, Test Error: 0.0060
# Updates: 800, Loss: 0.0386, Train Error: 0.0115, Test Error: 0.0120
# Updates: 810, Loss: 0.0381, Train Error: 0.0115, Test Error: 0.0120
# Updates: 820, Loss: 0.0397, Train Error: 0.0092, Test Error: 0.0160
# Updates: 830, Loss: 0.0392, Train Error: 0.0092, Test Error: 0.0160
# Updates: 840, Loss: 0.0372, Train Error: 0.0103, Test Error: 0.0100
# Updates: 850, Loss: 0.0376, Train Error: 0.0092, Test Error: 0.0100
# Updates: 860, Loss: 0.0370, Train Error: 0.0092, Test Error: 0.0100
# Updates: 870, Loss: 0.0375, Train Error: 0.0057, Test Error: 0.0040
# Updates: 880, Loss: 0.0362, Train Error: 0.0057, Test Error: 0.0040
# Updates: 890, Loss: 0.0354, Train Error: 0.0046, Test Error: 0.0040
# Updates: 900, Loss: 0.0371, Train Error: 0.0069, Test Error: 0.0040
# Updates: 910, Loss: 0.0374, Train Error: 0.0057, Test Error: 0.0040
# Updates: 920, Loss: 0.0344, Train Error: 0.0046, Test Error: 0.0040
# Updates: 930, Loss: 0.0330, Train Error: 0.0046, Test Error: 0.0040
# Updates: 940, Loss: 0.0329, Train Error: 0.0046, Test Error: 0.0040
# Updates: 950, Loss: 0.0334, Train Error: 0.0092, Test Error: 0.0100
# Updates: 960, Loss: 0.0332, Train Error: 0.0092, Test Error: 0.0100
# Updates: 970, Loss: 0.0341, Train Error: 0.0057, Test Error: 0.0040
# Updates: 980, Loss: 0.0331, Train Error: 0.0046, Test Error: 0.0040
# Updates: 990, Loss: 0.0336, Train Error: 0.0046, Test Error: 0.0040
# Final Results for Width 25:
# Final Training Error: 0.0046
# Final Test Error: 0.0040
#
# Training network with width 50
# Updates: 0, Loss: 0.4463, Train Error: 0.1800, Test Error: 0.1900
# Updates: 10, Loss: 0.3604, Train Error: 0.1491, Test Error: 0.1400
# Updates: 20, Loss: 0.2278, Train Error: 0.0826, Test Error: 0.1120
# Updates: 30, Loss: 0.2589, Train Error: 0.1261, Test Error: 0.1300
# Updates: 40, Loss: 0.1943, Train Error: 0.0745, Test Error: 0.0900
# Updates: 50, Loss: 0.1443, Train Error: 0.0550, Test Error: 0.0620
# Updates: 60, Loss: 0.1024, Train Error: 0.0275, Test Error: 0.0320
# Updates: 70, Loss: 0.1011, Train Error: 0.0252, Test Error: 0.0380
# Updates: 80, Loss: 0.0937, Train Error: 0.0298, Test Error: 0.0360
# Updates: 90, Loss: 0.1018, Train Error: 0.0344, Test Error: 0.0320
# Updates: 100, Loss: 0.0712, Train Error: 0.0161, Test Error: 0.0160
# Updates: 110, Loss: 0.0689, Train Error: 0.0195, Test Error: 0.0200
# Updates: 120, Loss: 0.0751, Train Error: 0.0218, Test Error: 0.0280
# Updates: 130, Loss: 0.0475, Train Error: 0.0138, Test Error: 0.0100
# Updates: 140, Loss: 0.0428, Train Error: 0.0080, Test Error: 0.0120
# Updates: 150, Loss: 0.0428, Train Error: 0.0080, Test Error: 0.0120
# Updates: 160, Loss: 0.0383, Train Error: 0.0069, Test Error: 0.0100
# Updates: 170, Loss: 0.0376, Train Error: 0.0069, Test Error: 0.0100
# Updates: 180, Loss: 0.0364, Train Error: 0.0092, Test Error: 0.0100
# Updates: 190, Loss: 0.0356, Train Error: 0.0092, Test Error: 0.0100
# Updates: 200, Loss: 0.0347, Train Error: 0.0069, Test Error: 0.0080
# Updates: 210, Loss: 0.0346, Train Error: 0.0069, Test Error: 0.0080
# Updates: 220, Loss: 0.0343, Train Error: 0.0080, Test Error: 0.0080
# Updates: 230, Loss: 0.0347, Train Error: 0.0080, Test Error: 0.0080
# Updates: 240, Loss: 0.0347, Train Error: 0.0080, Test Error: 0.0080
# Updates: 250, Loss: 0.0413, Train Error: 0.0115, Test Error: 0.0100
# Updates: 260, Loss: 0.0357, Train Error: 0.0080, Test Error: 0.0080
# Updates: 270, Loss: 0.0371, Train Error: 0.0080, Test Error: 0.0100
# Updates: 280, Loss: 0.0377, Train Error: 0.0080, Test Error: 0.0100
# Updates: 290, Loss: 0.0375, Train Error: 0.0080, Test Error: 0.0100
# Updates: 300, Loss: 0.0366, Train Error: 0.0080, Test Error: 0.0100
# Updates: 310, Loss: 0.0306, Train Error: 0.0069, Test Error: 0.0080
# Updates: 320, Loss: 0.0250, Train Error: 0.0069, Test Error: 0.0080
# Updates: 330, Loss: 0.0324, Train Error: 0.0034, Test Error: 0.0040
# Updates: 340, Loss: 0.0244, Train Error: 0.0011, Test Error: 0.0040
# Updates: 350, Loss: 0.0230, Train Error: 0.0011, Test Error: 0.0000
# Updates: 360, Loss: 0.0359, Train Error: 0.0046, Test Error: 0.0080
# Updates: 370, Loss: 0.0292, Train Error: 0.0034, Test Error: 0.0040
# Updates: 380, Loss: 0.0201, Train Error: 0.0011, Test Error: 0.0020
# Updates: 390, Loss: 0.0182, Train Error: 0.0011, Test Error: 0.0000
# Updates: 400, Loss: 0.0180, Train Error: 0.0011, Test Error: 0.0000
# Updates: 410, Loss: 0.0168, Train Error: 0.0000, Test Error: 0.0000
# Updates: 420, Loss: 0.0168, Train Error: 0.0000, Test Error: 0.0000
# Updates: 430, Loss: 0.0167, Train Error: 0.0000, Test Error: 0.0000
# Updates: 440, Loss: 0.0209, Train Error: 0.0034, Test Error: 0.0040
# Updates: 450, Loss: 0.0172, Train Error: 0.0011, Test Error: 0.0020
# Updates: 460, Loss: 0.0190, Train Error: 0.0023, Test Error: 0.0040
# Updates: 470, Loss: 0.0154, Train Error: 0.0000, Test Error: 0.0000
# Updates: 480, Loss: 0.0151, Train Error: 0.0000, Test Error: 0.0000
# Updates: 490, Loss: 0.0147, Train Error: 0.0000, Test Error: 0.0000
# Updates: 500, Loss: 0.0147, Train Error: 0.0000, Test Error: 0.0000
# Updates: 510, Loss: 0.0145, Train Error: 0.0000, Test Error: 0.0000
# Updates: 520, Loss: 0.0154, Train Error: 0.0000, Test Error: 0.0000
# Updates: 530, Loss: 0.0153, Train Error: 0.0000, Test Error: 0.0000
# Updates: 540, Loss: 0.0153, Train Error: 0.0000, Test Error: 0.0000
# Updates: 550, Loss: 0.0146, Train Error: 0.0000, Test Error: 0.0000
# Updates: 560, Loss: 0.0136, Train Error: 0.0000, Test Error: 0.0000
# Updates: 570, Loss: 0.0148, Train Error: 0.0000, Test Error: 0.0000
# Updates: 580, Loss: 0.0145, Train Error: 0.0000, Test Error: 0.0000
# Updates: 590, Loss: 0.0128, Train Error: 0.0000, Test Error: 0.0000
# Updates: 600, Loss: 0.0128, Train Error: 0.0000, Test Error: 0.0000
# Updates: 610, Loss: 0.0125, Train Error: 0.0000, Test Error: 0.0000
# Updates: 620, Loss: 0.0120, Train Error: 0.0000, Test Error: 0.0000
# Updates: 630, Loss: 0.0119, Train Error: 0.0000, Test Error: 0.0000
# Updates: 640, Loss: 0.0123, Train Error: 0.0000, Test Error: 0.0000
# Updates: 650, Loss: 0.0121, Train Error: 0.0000, Test Error: 0.0000
# Updates: 660, Loss: 0.0120, Train Error: 0.0000, Test Error: 0.0000
# Updates: 670, Loss: 0.0120, Train Error: 0.0000, Test Error: 0.0000
# Updates: 680, Loss: 0.0119, Train Error: 0.0000, Test Error: 0.0000
# Updates: 690, Loss: 0.0118, Train Error: 0.0000, Test Error: 0.0000
# Updates: 700, Loss: 0.0131, Train Error: 0.0000, Test Error: 0.0000
# Updates: 710, Loss: 0.0116, Train Error: 0.0000, Test Error: 0.0000
# Updates: 720, Loss: 0.0116, Train Error: 0.0000, Test Error: 0.0000
# Updates: 730, Loss: 0.0118, Train Error: 0.0000, Test Error: 0.0000
# Updates: 740, Loss: 0.0116, Train Error: 0.0000, Test Error: 0.0000
# Updates: 750, Loss: 0.0118, Train Error: 0.0000, Test Error: 0.0000
# Updates: 760, Loss: 0.0118, Train Error: 0.0000, Test Error: 0.0000
# Updates: 770, Loss: 0.0115, Train Error: 0.0000, Test Error: 0.0000
# Updates: 780, Loss: 0.0106, Train Error: 0.0000, Test Error: 0.0000
# Updates: 790, Loss: 0.0104, Train Error: 0.0000, Test Error: 0.0000
# Updates: 800, Loss: 0.0104, Train Error: 0.0000, Test Error: 0.0000
# Updates: 810, Loss: 0.0104, Train Error: 0.0000, Test Error: 0.0000
# Updates: 820, Loss: 0.0104, Train Error: 0.0000, Test Error: 0.0000
# Updates: 830, Loss: 0.0104, Train Error: 0.0000, Test Error: 0.0000
# Updates: 840, Loss: 0.0103, Train Error: 0.0000, Test Error: 0.0000
# Updates: 850, Loss: 0.0103, Train Error: 0.0000, Test Error: 0.0000
# Updates: 860, Loss: 0.0102, Train Error: 0.0000, Test Error: 0.0000
# Updates: 870, Loss: 0.0102, Train Error: 0.0000, Test Error: 0.0000
# Updates: 880, Loss: 0.0102, Train Error: 0.0000, Test Error: 0.0000
# Updates: 890, Loss: 0.0101, Train Error: 0.0000, Test Error: 0.0000
# Updates: 900, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 910, Loss: 0.0099, Train Error: 0.0000, Test Error: 0.0000
# Updates: 920, Loss: 0.0099, Train Error: 0.0000, Test Error: 0.0000
# Updates: 930, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 940, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 950, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 960, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 970, Loss: 0.0100, Train Error: 0.0000, Test Error: 0.0000
# Updates: 980, Loss: 0.0098, Train Error: 0.0000, Test Error: 0.0000
# Updates: 990, Loss: 0.0097, Train Error: 0.0000, Test Error: 0.0000
# Final Results for Width 50:
# Final Training Error: 0.0000
# Final Test Error: 0.0000
#
# Training network with width 100
# Updates: 0, Loss: 3.9265, Train Error: 0.4461, Test Error: 0.4420
# Updates: 10, Loss: 1.5576, Train Error: 0.4461, Test Error: 0.4420
# Updates: 20, Loss: 0.2912, Train Error: 0.1261, Test Error: 0.1240
# Updates: 30, Loss: 0.6496, Train Error: 0.2351, Test Error: 0.2300
# Updates: 40, Loss: 0.0781, Train Error: 0.0333, Test Error: 0.0440
# Updates: 50, Loss: 0.0396, Train Error: 0.0115, Test Error: 0.0120
# Updates: 60, Loss: 0.2008, Train Error: 0.0860, Test Error: 0.0840
# Updates: 70, Loss: 0.1175, Train Error: 0.0470, Test Error: 0.0540
# Updates: 80, Loss: 0.0137, Train Error: 0.0000, Test Error: 0.0020
# Updates: 90, Loss: 0.0130, Train Error: 0.0000, Test Error: 0.0020
# Updates: 100, Loss: 0.0109, Train Error: 0.0000, Test Error: 0.0020
# Updates: 110, Loss: 0.0108, Train Error: 0.0000, Test Error: 0.0020
# Updates: 120, Loss: 0.0107, Train Error: 0.0000, Test Error: 0.0020
# Updates: 130, Loss: 0.0269, Train Error: 0.0023, Test Error: 0.0060
# Updates: 140, Loss: 0.0232, Train Error: 0.0011, Test Error: 0.0060
# Updates: 150, Loss: 0.0082, Train Error: 0.0000, Test Error: 0.0020
# Updates: 160, Loss: 0.0086, Train Error: 0.0000, Test Error: 0.0020
# Updates: 170, Loss: 0.0080, Train Error: 0.0000, Test Error: 0.0020
# Updates: 180, Loss: 0.0085, Train Error: 0.0000, Test Error: 0.0020
# Updates: 190, Loss: 0.0079, Train Error: 0.0000, Test Error: 0.0020
# Updates: 200, Loss: 0.0078, Train Error: 0.0000, Test Error: 0.0020
# Updates: 210, Loss: 0.0091, Train Error: 0.0000, Test Error: 0.0020
# Updates: 220, Loss: 0.0094, Train Error: 0.0000, Test Error: 0.0020
# Updates: 230, Loss: 0.0094, Train Error: 0.0000, Test Error: 0.0020
# Updates: 240, Loss: 0.0109, Train Error: 0.0011, Test Error: 0.0020
# Updates: 250, Loss: 0.0085, Train Error: 0.0000, Test Error: 0.0020
# Updates: 260, Loss: 0.0078, Train Error: 0.0000, Test Error: 0.0020
# Updates: 270, Loss: 0.0072, Train Error: 0.0000, Test Error: 0.0020
# Updates: 280, Loss: 0.0069, Train Error: 0.0000, Test Error: 0.0020
# Updates: 290, Loss: 0.0070, Train Error: 0.0000, Test Error: 0.0020
# Updates: 300, Loss: 0.0069, Train Error: 0.0000, Test Error: 0.0020
# Updates: 310, Loss: 0.0064, Train Error: 0.0000, Test Error: 0.0020
# Updates: 320, Loss: 0.0064, Train Error: 0.0000, Test Error: 0.0020
# Updates: 330, Loss: 0.0064, Train Error: 0.0000, Test Error: 0.0020
# Updates: 340, Loss: 0.0061, Train Error: 0.0000, Test Error: 0.0020
# Updates: 350, Loss: 0.0052, Train Error: 0.0000, Test Error: 0.0020
# Updates: 360, Loss: 0.0050, Train Error: 0.0000, Test Error: 0.0020
# Updates: 370, Loss: 0.0048, Train Error: 0.0000, Test Error: 0.0020
# Updates: 380, Loss: 0.0048, Train Error: 0.0000, Test Error: 0.0020
# Updates: 390, Loss: 0.0048, Train Error: 0.0000, Test Error: 0.0020
# Updates: 400, Loss: 0.0045, Train Error: 0.0000, Test Error: 0.0020
# Updates: 410, Loss: 0.0044, Train Error: 0.0000, Test Error: 0.0020
# Updates: 420, Loss: 0.0046, Train Error: 0.0000, Test Error: 0.0020
# Updates: 430, Loss: 0.0050, Train Error: 0.0000, Test Error: 0.0020
# Updates: 440, Loss: 0.0049, Train Error: 0.0000, Test Error: 0.0020
# Updates: 450, Loss: 0.0044, Train Error: 0.0000, Test Error: 0.0020
# Updates: 460, Loss: 0.0042, Train Error: 0.0000, Test Error: 0.0020
# Updates: 470, Loss: 0.0036, Train Error: 0.0000, Test Error: 0.0020
# Updates: 480, Loss: 0.0036, Train Error: 0.0000, Test Error: 0.0020
# Updates: 490, Loss: 0.0036, Train Error: 0.0000, Test Error: 0.0020
# Updates: 500, Loss: 0.0037, Train Error: 0.0000, Test Error: 0.0020
# Updates: 510, Loss: 0.0035, Train Error: 0.0000, Test Error: 0.0020
# Updates: 520, Loss: 0.0035, Train Error: 0.0000, Test Error: 0.0020
# Updates: 530, Loss: 0.0035, Train Error: 0.0000, Test Error: 0.0020
# Updates: 540, Loss: 0.0034, Train Error: 0.0000, Test Error: 0.0020
# Updates: 550, Loss: 0.0034, Train Error: 0.0000, Test Error: 0.0020
# Updates: 560, Loss: 0.0034, Train Error: 0.0000, Test Error: 0.0020
# Updates: 570, Loss: 0.0034, Train Error: 0.0000, Test Error: 0.0020
# Updates: 580, Loss: 0.0034, Train Error: 0.0000, Test Error: 0.0020
# Updates: 590, Loss: 0.0033, Train Error: 0.0000, Test Error: 0.0020
# Updates: 600, Loss: 0.0033, Train Error: 0.0000, Test Error: 0.0020
# Updates: 610, Loss: 0.0033, Train Error: 0.0000, Test Error: 0.0020
# Updates: 620, Loss: 0.0032, Train Error: 0.0000, Test Error: 0.0020
# Updates: 630, Loss: 0.0031, Train Error: 0.0000, Test Error: 0.0020
# Updates: 640, Loss: 0.0031, Train Error: 0.0000, Test Error: 0.0020
# Updates: 650, Loss: 0.0031, Train Error: 0.0000, Test Error: 0.0020
# Updates: 660, Loss: 0.0031, Train Error: 0.0000, Test Error: 0.0020
# Updates: 670, Loss: 0.0031, Train Error: 0.0000, Test Error: 0.0020
# Updates: 680, Loss: 0.0030, Train Error: 0.0000, Test Error: 0.0020
# Updates: 690, Loss: 0.0030, Train Error: 0.0000, Test Error: 0.0020
# Updates: 700, Loss: 0.0029, Train Error: 0.0000, Test Error: 0.0020
# Updates: 710, Loss: 0.0029, Train Error: 0.0000, Test Error: 0.0020
# Updates: 720, Loss: 0.0030, Train Error: 0.0000, Test Error: 0.0020
# Updates: 730, Loss: 0.0029, Train Error: 0.0000, Test Error: 0.0020
# Updates: 740, Loss: 0.0029, Train Error: 0.0000, Test Error: 0.0020
# Updates: 750, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 760, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 770, Loss: 0.0029, Train Error: 0.0000, Test Error: 0.0020
# Updates: 780, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 790, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 800, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 810, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 820, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 830, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 840, Loss: 0.0028, Train Error: 0.0000, Test Error: 0.0020
# Updates: 850, Loss: 0.0027, Train Error: 0.0000, Test Error: 0.0020
# Updates: 860, Loss: 0.0027, Train Error: 0.0000, Test Error: 0.0020
# Updates: 870, Loss: 0.0027, Train Error: 0.0000, Test Error: 0.0020
# Updates: 880, Loss: 0.0027, Train Error: 0.0000, Test Error: 0.0020
# Updates: 890, Loss: 0.0027, Train Error: 0.0000, Test Error: 0.0020
# Updates: 900, Loss: 0.0026, Train Error: 0.0000, Test Error: 0.0020
# Updates: 910, Loss: 0.0026, Train Error: 0.0000, Test Error: 0.0020
# Updates: 920, Loss: 0.0026, Train Error: 0.0000, Test Error: 0.0020
# Updates: 930, Loss: 0.0026, Train Error: 0.0000, Test Error: 0.0020
# Updates: 940, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Updates: 950, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Updates: 960, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Updates: 970, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Updates: 980, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Updates: 990, Loss: 0.0025, Train Error: 0.0000, Test Error: 0.0020
# Final Results for Width 100:
# Final Training Error: 0.0000
# Final Test Error: 0.0020
