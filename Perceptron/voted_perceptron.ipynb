# %%
import numpy as np

def load_data(filename):
    # Load data directly as float
    data = np.genfromtxt(filename, delimiter=',')
    
    # Split into features and labels
    X = data[:, :-1]
    y = data[:, -1]
    
    # Add bias term
    X_with_bias = np.column_stack([np.ones(len(X)), X])
    
    # Convert 0/1 labels to -1/1
    y = 2 * y - 1
    
    return X_with_bias, y

def voted_perceptron(X, y, T=10):
    """
    Voted Perceptron implementation
    X: features with bias term (n_samples, n_features + 1)
    y: labels (-1 or 1)
    T: maximum number of epochs
    
    Returns:
    w_list: list of weight vectors
    c_list: list of counts for each weight vector
    """
    n_samples, n_features = X.shape
    
    # Initialize lists to store weights and their counts
    w_list = []
    c_list = []
    
    # Initialize first weight vector and its count
    w = np.zeros(n_features)
    c = 0
    
    # Training loop
    for epoch in range(T):
        for i in range(n_samples):
            prediction = np.sign(np.dot(w, X[i]))
            
            if prediction * y[i] <= 0:  # Mistake was made
                # Store current weight vector and its count
                if c > 0:
                    w_list.append(w.copy())
                    c_list.append(c)
                
                # Update weights
                w = w + y[i] * X[i]
                c = 1
            else:
                c += 1  # Increment count for current weights
                
        print(f"Epoch {epoch + 1}, distinct weight vectors: {len(w_list)}")
    
    # Add the last weight vector and its count
    if c > 0:
        w_list.append(w)
        c_list.append(c)
    
    return np.array(w_list), np.array(c_list)

def predict_voted(X, w_list, c_list):
    """
    Make predictions using voted weights
    Returns both the final prediction and individual predictions
    """
    # Get predictions from each weight vector
    predictions = np.sign(np.dot(X, w_list.T))  # shape: (n_samples, n_weights)
    
    # Weight each prediction by its count
    weighted_predictions = predictions * c_list
    
    # Final prediction is the sign of the sum of weighted predictions
    final_predictions = np.sign(weighted_predictions.sum(axis=1))
    
    return final_predictions

def evaluate(y_true, y_pred):
    """Calculate prediction error"""
    return np.mean(y_true != y_pred)

# %%
# Load data
print("Loading data...")
train_data, train_labels = load_data('train.csv')
test_data, test_labels = load_data('test.csv')

# Train voted perceptron
print("\nTraining Voted Perceptron...")
w_list, c_list = voted_perceptron(train_data, train_labels, T=10)

# Evaluate on training set
train_pred = predict_voted(train_data, w_list, c_list)
train_error = evaluate(train_labels, train_pred)
train_correct = sum(train_pred == train_labels)

# Evaluate on test set
test_pred = predict_voted(test_data, w_list, c_list)
test_error = evaluate(test_labels, test_pred)

# Report results
print("\nResults:")
print(f"Number of distinct weight vectors: {len(w_list)}")
print(f"Number of correctly predicted training examples: {train_correct}")
print(f"Training error rate: {train_error:.4f}")
print(f"Test error rate: {test_error:.4f}")

print("\nWeight vectors and their counts:")
for i, (w, c) in enumerate(zip(w_list, c_list)):
    print(f"\nWeight vector {i+1}:")
    print(f"Count (survival time): {c}")
    print("Weights by feature:")
    feature_names = ['bias', 'variance', 'skewness', 'curtosis', 'entropy']
    for name, weight in zip(feature_names, w):
        print(f"{name}: {weight:.4f}")
# Out:
# Loading data...
#
# Training Voted Perceptron...
# Epoch 1, distinct weight vectors: 52
# Epoch 2, distinct weight vectors: 82
# Epoch 3, distinct weight vectors: 104
# Epoch 4, distinct weight vectors: 129
# Epoch 5, distinct weight vectors: 149
# Epoch 6, distinct weight vectors: 170
# Epoch 7, distinct weight vectors: 192
# Epoch 8, distinct weight vectors: 217
# Epoch 9, distinct weight vectors: 234
# Epoch 10, distinct weight vectors: 258
#
# Results:
# Number of distinct weight vectors: 259
# Number of correctly predicted training examples: 859
# Training error rate: 0.0149
# Test error rate: 0.0140
#
# Weight vectors and their counts:
#
# Weight vector 1:
# Count (survival time): 2
# Weights by feature:
# bias: -1.0000
# variance: -3.8481
# skewness: -10.1539
# curtosis: 3.8561
# entropy: 4.2228
#
# Weight vector 2:
# Count (survival time): 1
# Weights by feature:
# bias: -2.0000
# variance: -3.8001
# skewness: -8.5502
# curtosis: -4.6195
# entropy: 3.4672
#
# Weight vector 3:
# Count (survival time): 8
# Weights by feature:
# bias: -1.0000
# variance: -5.0668
# skewness: -5.7319
# curtosis: -7.0455
# entropy: 1.5810
#
# Weight vector 4:
# Count (survival time): 3
# Weights by feature:
# bias: 0.0000
# variance: -7.1197
# skewness: -1.8934
# curtosis: -7.8409
# entropy: 0.3672
#
# Weight vector 5:
# Count (survival time): 7
# Weights by feature:
# bias: 1.0000
# variance: -10.3889
# skewness: -14.6340
# curtosis: 7.7164
# entropy: 0.2254
#
# Weight vector 6:
# Count (survival time): 5
# Weights by feature:
# bias: 2.0000
# variance: -14.3093
# skewness: -10.5617
# curtosis: 7.4796
# entropy: -1.8897
#
# Weight vector 7:
# Count (survival time): 9
# Weights by feature:
# bias: 1.0000
# variance: -17.7760
# skewness: -6.4893
# curtosis: 3.1914
# entropy: -3.4315
#
# Weight vector 8:
# Count (survival time): 10
# Weights by feature:
# bias: 0.0000
# variance: -17.6582
# skewness: -4.9104
# curtosis: -4.8386
# entropy: -3.4035
#
# Weight vector 9:
# Count (survival time): 2
# Weights by feature:
# bias: 1.0000
# variance: -16.2081
# skewness: -1.3037
# curtosis: -8.8943
# entropy: -5.0001
#
# Weight vector 10:
# Count (survival time): 1
# Weights by feature:
# bias: 2.0000
# variance: -20.8846
# skewness: -6.9673
# curtosis: 2.0747
# entropy: -5.3346
#
# Weight vector 11:
# Count (survival time): 3
# Weights by feature:
# bias: 1.0000
# variance: -18.2367
# skewness: -17.1047
# curtosis: 3.4057
# entropy: 0.1361
#
# Weight vector 12:
# Count (survival time): 1
# Weights by feature:
# bias: 2.0000
# variance: -18.1207
# skewness: -13.8828
# curtosis: -0.0245
# entropy: -2.7096
#
# Weight vector 13:
# Count (survival time): 8
# Weights by feature:
# bias: 3.0000
# variance: -20.7087
# skewness: -10.0174
# curtosis: -0.3581
# entropy: -3.9893
#
# Weight vector 14:
# Count (survival time): 2
# Weights by feature:
# bias: 4.0000
# variance: -20.5875
# skewness: -9.7939
# curtosis: -0.8314
# entropy: -3.0190
#
# Weight vector 15:
# Count (survival time): 10
# Weights by feature:
# bias: 5.0000
# variance: -21.0783
# skewness: -6.9487
# curtosis: -4.4750
# entropy: -6.1194
#
# Weight vector 16:
# Count (survival time): 2
# Weights by feature:
# bias: 6.0000
# variance: -18.8840
# skewness: -2.3984
# curtosis: -9.4510
# entropy: -8.8448
#
# Weight vector 17:
# Count (survival time): 3
# Weights by feature:
# bias: 7.0000
# variance: -22.9058
# skewness: -10.7024
# curtosis: 3.1040
# entropy: -10.3547
#
# Weight vector 18:
# Count (survival time): 14
# Weights by feature:
# bias: 8.0000
# variance: -22.7955
# skewness: -8.7283
# curtosis: -0.2628
# entropy: -11.0073
#
# Weight vector 19:
# Count (survival time): 6
# Weights by feature:
# bias: 9.0000
# variance: -22.4947
# skewness: -8.5545
# curtosis: -2.0170
# entropy: -10.5181
#
# Weight vector 20:
# Count (survival time): 11
# Weights by feature:
# bias: 10.0000
# variance: -21.8942
# skewness: -6.6218
# curtosis: -5.3058
# entropy: -10.8422
#
# Weight vector 21:
# Count (survival time): 17
# Weights by feature:
# bias: 11.0000
# variance: -20.8390
# skewness: -5.4361
# curtosis: -7.9469
# entropy: -10.7319
#
# Weight vector 22:
# Count (survival time): 27
# Weights by feature:
# bias: 10.0000
# variance: -20.8909
# skewness: -12.4882
# curtosis: -5.8928
# entropy: -7.5811
#
# Weight vector 23:
# Count (survival time): 30
# Weights by feature:
# bias: 9.0000
# variance: -22.0341
# skewness: -8.7469
# curtosis: -11.4705
# entropy: -6.9453
#
# Weight vector 24:
# Count (survival time): 3
# Weights by feature:
# bias: 8.0000
# variance: -19.3862
# skewness: -18.8843
# curtosis: -10.1395
# entropy: -1.4746
#
# Weight vector 25:
# Count (survival time): 12
# Weights by feature:
# bias: 9.0000
# variance: -18.4192
# skewness: -15.0417
# curtosis: -15.0709
# entropy: -5.6069
#
# Weight vector 26:
# Count (survival time): 6
# Weights by feature:
# bias: 8.0000
# variance: -18.7484
# skewness: -10.5865
# curtosis: -19.6427
# entropy: -4.6181
#
# Weight vector 27:
# Count (survival time): 7
# Weights by feature:
# bias: 9.0000
# variance: -20.4588
# skewness: -15.3645
# curtosis: -13.4318
# entropy: -4.2207
#
# Weight vector 28:
# Count (survival time): 31
# Weights by feature:
# bias: 10.0000
# variance: -19.8994
# skewness: -15.6749
# curtosis: -13.2487
# entropy: -3.7742
#
# Weight vector 29:
# Count (survival time): 13
# Weights by feature:
# bias: 9.0000
# variance: -20.4189
# skewness: -12.4116
# curtosis: -16.3382
# entropy: -2.7893
#
# Weight vector 30:
# Count (survival time): 2
# Weights by feature:
# bias: 10.0000
# variance: -23.5612
# skewness: -25.4481
# curtosis: -0.6609
# entropy: -3.4510
#
# Weight vector 31:
# Count (survival time): 1
# Weights by feature:
# bias: 9.0000
# variance: -25.2869
# skewness: -20.9784
# curtosis: -8.8828
# entropy: -1.6437
#
# Weight vector 32:
# Count (survival time): 30
# Weights by feature:
# bias: 10.0000
# variance: -32.3290
# skewness: -11.7784
# curtosis: -8.6235
# entropy: -6.3269
#
# Weight vector 33:
# Count (survival time): 53
# Weights by feature:
# bias: 11.0000
# variance: -30.6491
# skewness: -7.5716
# curtosis: -13.1633
# entropy: -8.7200
#
# Weight vector 34:
# Count (survival time): 15
# Weights by feature:
# bias: 12.0000
# variance: -29.2973
# skewness: -6.5121
# curtosis: -15.5070
# entropy: -8.3200
#
# Weight vector 35:
# Count (survival time): 24
# Weights by feature:
# bias: 13.0000
# variance: -32.8033
# skewness: -19.0788
# curtosis: -0.3464
# entropy: -9.0721
#
# Weight vector 36:
# Count (survival time): 18
# Weights by feature:
# bias: 14.0000
# variance: -31.0702
# skewness: -15.1244
# curtosis: -5.0876
# entropy: -11.5738
#
# Weight vector 37:
# Count (survival time): 17
# Weights by feature:
# bias: 13.0000
# variance: -32.8918
# skewness: -8.6496
# curtosis: -13.1390
# entropy: -11.1553
#
# Weight vector 38:
# Count (survival time): 5
# Weights by feature:
# bias: 12.0000
# variance: -32.1049
# skewness: -18.2159
# curtosis: -9.3523
# entropy: -3.6519
#
# Weight vector 39:
# Count (survival time): 18
# Weights by feature:
# bias: 13.0000
# variance: -30.5972
# skewness: -16.2563
# curtosis: -12.4107
# entropy: -3.7743
#
# Weight vector 40:
# Count (survival time): 104
# Weights by feature:
# bias: 14.0000
# variance: -29.5855
# skewness: -15.3541
# curtosis: -14.7613
# entropy: -3.3472
#
# Weight vector 41:
# Count (survival time): 21
# Weights by feature:
# bias: 15.0000
# variance: -27.1938
# skewness: -10.7976
# curtosis: -19.7501
# entropy: -6.2459
#
# Weight vector 42:
# Count (survival time): 27
# Weights by feature:
# bias: 16.0000
# variance: -30.7991
# skewness: -16.7716
# curtosis: -9.6585
# entropy: -7.0743
#
# Weight vector 43:
# Count (survival time): 27
# Weights by feature:
# bias: 15.0000
# variance: -30.6380
# skewness: -10.3092
# curtosis: -18.0158
# entropy: -5.5527
#
# Weight vector 44:
# Count (survival time): 12
# Weights by feature:
# bias: 16.0000
# variance: -34.3341
# skewness: -23.9871
# curtosis: -0.4363
# entropy: -8.1708
#
# Weight vector 45:
# Count (survival time): 1
# Weights by feature:
# bias: 17.0000
# variance: -33.4390
# skewness: -19.2133
# curtosis: -5.2794
# entropy: -13.7617
#
# Weight vector 46:
# Count (survival time): 113
# Weights by feature:
# bias: 16.0000
# variance: -33.9585
# skewness: -15.9500
# curtosis: -8.3689
# entropy: -12.7768
#
# Weight vector 47:
# Count (survival time): 1
# Weights by feature:
# bias: 15.0000
# variance: -34.2877
# skewness: -11.4948
# curtosis: -12.9407
# entropy: -11.7880
#
# Weight vector 48:
# Count (survival time): 10
# Weights by feature:
# bias: 16.0000
# variance: -32.2567
# skewness: -9.6428
# curtosis: -15.9528
# entropy: -11.7850
#
# Weight vector 49:
# Count (survival time): 28
# Weights by feature:
# bias: 15.0000
# variance: -31.8939
# skewness: -17.9323
# curtosis: -14.0315
# entropy: -8.4518
#
# Weight vector 50:
# Count (survival time): 48
# Weights by feature:
# bias: 16.0000
# variance: -29.8762
# skewness: -16.1341
# curtosis: -16.9896
# entropy: -8.2419
#
# Weight vector 51:
# Count (survival time): 7
# Weights by feature:
# bias: 17.0000
# variance: -28.6564
# skewness: -14.0359
# curtosis: -20.1850
# entropy: -8.1135
#
# Weight vector 52:
# Count (survival time): 29
# Weights by feature:
# bias: 16.0000
# variance: -27.8695
# skewness: -23.6022
# curtosis: -16.3983
# entropy: -0.6101
#
# Weight vector 53:
# Count (survival time): 24
# Weights by feature:
# bias: 17.0000
# variance: -34.2059
# skewness: -14.3174
# curtosis: -16.3840
# entropy: -7.3945
#
# Weight vector 54:
# Count (survival time): 28
# Weights by feature:
# bias: 16.0000
# variance: -31.5580
# skewness: -24.4548
# curtosis: -15.0530
# entropy: -1.9238
#
# Weight vector 55:
# Count (survival time): 27
# Weights by feature:
# bias: 17.0000
# variance: -30.1079
# skewness: -20.8481
# curtosis: -19.1087
# entropy: -3.5204
#
# Weight vector 56:
# Count (survival time): 2
# Weights by feature:
# bias: 18.0000
# variance: -27.9136
# skewness: -16.2978
# curtosis: -24.0847
# entropy: -6.2458
#
# Weight vector 57:
# Count (survival time): 23
# Weights by feature:
# bias: 19.0000
# variance: -31.9354
# skewness: -24.6018
# curtosis: -11.5297
# entropy: -7.7557
#
# Weight vector 58:
# Count (survival time): 11
# Weights by feature:
# bias: 20.0000
# variance: -31.3349
# skewness: -22.6691
# curtosis: -14.8185
# entropy: -8.0798
#
# Weight vector 59:
# Count (survival time): 11
# Weights by feature:
# bias: 21.0000
# variance: -30.2797
# skewness: -21.4834
# curtosis: -17.4596
# entropy: -7.9695
#
# Weight vector 60:
# Count (survival time): 78
# Weights by feature:
# bias: 22.0000
# variance: -28.7901
# skewness: -18.0546
# curtosis: -21.4905
# entropy: -9.3954
#
# Weight vector 61:
# Count (survival time): 6
# Weights by feature:
# bias: 21.0000
# variance: -29.1193
# skewness: -13.5994
# curtosis: -26.0623
# entropy: -8.4066
#
# Weight vector 62:
# Count (survival time): 38
# Weights by feature:
# bias: 22.0000
# variance: -30.8297
# skewness: -18.3774
# curtosis: -19.8514
# entropy: -8.0092
#
# Weight vector 63:
# Count (survival time): 13
# Weights by feature:
# bias: 21.0000
# variance: -31.3492
# skewness: -15.1141
# curtosis: -22.9409
# entropy: -7.0243
#
# Weight vector 64:
# Count (survival time): 2
# Weights by feature:
# bias: 22.0000
# variance: -34.4915
# skewness: -28.1506
# curtosis: -7.2636
# entropy: -7.6860
#
# Weight vector 65:
# Count (survival time): 6
# Weights by feature:
# bias: 21.0000
# variance: -36.2172
# skewness: -23.6809
# curtosis: -15.4855
# entropy: -5.8787
#
# Weight vector 66:
# Count (survival time): 25
# Weights by feature:
# bias: 20.0000
# variance: -37.1469
# skewness: -19.8838
# curtosis: -20.1284
# entropy: -5.5830
#
# Weight vector 67:
# Count (survival time): 20
# Weights by feature:
# bias: 21.0000
# variance: -35.4670
# skewness: -15.6770
# curtosis: -24.6682
# entropy: -7.9761
#
# Weight vector 68:
# Count (survival time): 23
# Weights by feature:
# bias: 22.0000
# variance: -38.6975
# skewness: -22.8905
# curtosis: -13.0249
# entropy: -8.9222
#
# Weight vector 69:
# Count (survival time): 10
# Weights by feature:
# bias: 21.0000
# variance: -38.0528
# skewness: -18.2843
# curtosis: -21.3719
# entropy: -6.2123
#
# Weight vector 70:
# Count (survival time): 74
# Weights by feature:
# bias: 22.0000
# variance: -36.7010
# skewness: -17.2248
# curtosis: -23.7156
# entropy: -5.8123
#
# Weight vector 71:
# Count (survival time): 5
# Weights by feature:
# bias: 21.0000
# variance: -35.9141
# skewness: -26.7911
# curtosis: -19.9289
# entropy: 1.6911
#
# Weight vector 72:
# Count (survival time): 58
# Weights by feature:
# bias: 22.0000
# variance: -34.4064
# skewness: -24.8315
# curtosis: -22.9873
# entropy: 1.5687
#
# Weight vector 73:
# Count (survival time): 26
# Weights by feature:
# bias: 23.0000
# variance: -33.7246
# skewness: -19.9811
# curtosis: -28.2006
# entropy: -4.5356
#
# Weight vector 74:
# Count (survival time): 38
# Weights by feature:
# bias: 24.0000
# variance: -36.2619
# skewness: -26.9401
# curtosis: -19.3952
# entropy: -3.0067
#
# Weight vector 75:
# Count (survival time): 53
# Weights by feature:
# bias: 25.0000
# variance: -33.8702
# skewness: -22.3836
# curtosis: -24.3840
# entropy: -5.9054
#
# Weight vector 76:
# Count (survival time): 22
# Weights by feature:
# bias: 24.0000
# variance: -34.3897
# skewness: -19.1203
# curtosis: -27.4735
# entropy: -4.9205
#
# Weight vector 77:
# Count (survival time): 12
# Weights by feature:
# bias: 25.0000
# variance: -38.0858
# skewness: -32.7982
# curtosis: -9.8940
# entropy: -7.5386
#
# Weight vector 78:
# Count (survival time): 1
# Weights by feature:
# bias: 26.0000
# variance: -37.1907
# skewness: -28.0244
# curtosis: -14.7371
# entropy: -13.1295
#
# Weight vector 79:
# Count (survival time): 113
# Weights by feature:
# bias: 25.0000
# variance: -37.7102
# skewness: -24.7611
# curtosis: -17.8266
# entropy: -12.1446
#
# Weight vector 80:
# Count (survival time): 1
# Weights by feature:
# bias: 24.0000
# variance: -38.0394
# skewness: -20.3059
# curtosis: -22.3984
# entropy: -11.1558
#
# Weight vector 81:
# Count (survival time): 38
# Weights by feature:
# bias: 25.0000
# variance: -36.0084
# skewness: -18.4539
# curtosis: -25.4105
# entropy: -11.1528
#
# Weight vector 82:
# Count (survival time): 49
# Weights by feature:
# bias: 26.0000
# variance: -33.9907
# skewness: -16.6557
# curtosis: -28.3686
# entropy: -10.9429
#
# Weight vector 83:
# Count (survival time): 114
# Weights by feature:
# bias: 27.0000
# variance: -34.7113
# skewness: -23.4140
# curtosis: -22.5278
# entropy: -10.3192
#
# Weight vector 84:
# Count (survival time): 2
# Weights by feature:
# bias: 28.0000
# variance: -32.5170
# skewness: -18.8637
# curtosis: -27.5038
# entropy: -13.0446
#
# Weight vector 85:
# Count (survival time): 34
# Weights by feature:
# bias: 29.0000
# variance: -36.5388
# skewness: -27.1677
# curtosis: -14.9488
# entropy: -14.5545
#
# Weight vector 86:
# Count (survival time): 11
# Weights by feature:
# bias: 30.0000
# variance: -35.4836
# skewness: -25.9820
# curtosis: -17.5899
# entropy: -14.4442
#
# Weight vector 87:
# Count (survival time): 63
# Weights by feature:
# bias: 31.0000
# variance: -33.9940
# skewness: -22.5532
# curtosis: -21.6208
# entropy: -15.8701
#
# Weight vector 88:
# Count (survival time): 15
# Weights by feature:
# bias: 30.0000
# variance: -31.3461
# skewness: -32.6906
# curtosis: -20.2898
# entropy: -10.3994
#
# Weight vector 89:
# Count (survival time): 44
# Weights by feature:
# bias: 29.0000
# variance: -31.6754
# skewness: -28.2354
# curtosis: -24.8616
# entropy: -9.4106
#
# Weight vector 90:
# Count (survival time): 49
# Weights by feature:
# bias: 28.0000
# variance: -32.1949
# skewness: -24.9721
# curtosis: -27.9511
# entropy: -8.4257
#
# Weight vector 91:
# Count (survival time): 17
# Weights by feature:
# bias: 27.0000
# variance: -32.7144
# skewness: -21.7088
# curtosis: -31.0406
# entropy: -7.4408
#
# Weight vector 92:
# Count (survival time): 23
# Weights by feature:
# bias: 28.0000
# variance: -35.9449
# skewness: -28.9223
# curtosis: -19.3973
# entropy: -8.3869
#
# Weight vector 93:
# Count (survival time): 211
# Weights by feature:
# bias: 27.0000
# variance: -35.3002
# skewness: -24.3161
# curtosis: -27.7443
# entropy: -5.6770
#
# Weight vector 94:
# Count (survival time): 11
# Weights by feature:
# bias: 28.0000
# variance: -32.9085
# skewness: -19.7596
# curtosis: -32.7331
# entropy: -8.5757
#
# Weight vector 95:
# Count (survival time): 37
# Weights by feature:
# bias: 29.0000
# variance: -36.6658
# skewness: -28.0512
# curtosis: -22.4299
# entropy: -8.1951
#
# Weight vector 96:
# Count (survival time): 27
# Weights by feature:
# bias: 28.0000
# variance: -36.5047
# skewness: -21.5888
# curtosis: -30.7872
# entropy: -6.6735
#
# Weight vector 97:
# Count (survival time): 12
# Weights by feature:
# bias: 29.0000
# variance: -40.2008
# skewness: -35.2667
# curtosis: -13.2077
# entropy: -9.2916
#
# Weight vector 98:
# Count (survival time): 1
# Weights by feature:
# bias: 30.0000
# variance: -39.3057
# skewness: -30.4929
# curtosis: -18.0508
# entropy: -14.8825
#
# Weight vector 99:
# Count (survival time): 113
# Weights by feature:
# bias: 29.0000
# variance: -39.8251
# skewness: -27.2296
# curtosis: -21.1403
# entropy: -13.8976
#
# Weight vector 100:
# Count (survival time): 1
# Weights by feature:
# bias: 28.0000
# variance: -40.1543
# skewness: -22.7744
# curtosis: -25.7121
# entropy: -12.9088
#
# Weight vector 101:
# Count (survival time): 38
# Weights by feature:
# bias: 29.0000
# variance: -38.1233
# skewness: -20.9224
# curtosis: -28.7242
# entropy: -12.9058
#
# Weight vector 102:
# Count (survival time): 49
# Weights by feature:
# bias: 30.0000
# variance: -36.1056
# skewness: -19.1242
# curtosis: -31.6823
# entropy: -12.6959
#
# Weight vector 103:
# Count (survival time): 6
# Weights by feature:
# bias: 31.0000
# variance: -36.8263
# skewness: -25.8825
# curtosis: -25.8415
# entropy: -12.0722
#
# Weight vector 104:
# Count (survival time): 29
# Weights by feature:
# bias: 30.0000
# variance: -36.0394
# skewness: -35.4488
# curtosis: -22.0548
# entropy: -4.5688
#
# Weight vector 105:
# Count (survival time): 52
# Weights by feature:
# bias: 31.0000
# variance: -42.3758
# skewness: -26.1640
# curtosis: -22.0405
# entropy: -11.3532
#
# Weight vector 106:
# Count (survival time): 3
# Weights by feature:
# bias: 32.0000
# variance: -40.9257
# skewness: -22.5573
# curtosis: -26.0962
# entropy: -12.9498
#
# Weight vector 107:
# Count (survival time): 24
# Weights by feature:
# bias: 31.0000
# variance: -38.2778
# skewness: -32.6947
# curtosis: -24.7652
# entropy: -7.4791
#
# Weight vector 108:
# Count (survival time): 125
# Weights by feature:
# bias: 32.0000
# variance: -36.0835
# skewness: -28.1444
# curtosis: -29.7412
# entropy: -10.2045
#
# Weight vector 109:
# Count (survival time): 6
# Weights by feature:
# bias: 31.0000
# variance: -36.4128
# skewness: -23.6892
# curtosis: -34.3130
# entropy: -9.2157
#
# Weight vector 110:
# Count (survival time): 38
# Weights by feature:
# bias: 32.0000
# variance: -38.1232
# skewness: -28.4672
# curtosis: -28.1021
# entropy: -8.8183
#
# Weight vector 111:
# Count (survival time): 13
# Weights by feature:
# bias: 31.0000
# variance: -38.6427
# skewness: -25.2039
# curtosis: -31.1916
# entropy: -7.8334
#
# Weight vector 112:
# Count (survival time): 2
# Weights by feature:
# bias: 32.0000
# variance: -41.7850
# skewness: -38.2404
# curtosis: -15.5143
# entropy: -8.4951
#
# Weight vector 113:
# Count (survival time): 6
# Weights by feature:
# bias: 31.0000
# variance: -43.5107
# skewness: -33.7707
# curtosis: -23.7362
# entropy: -6.6878
#
# Weight vector 114:
# Count (survival time): 25
# Weights by feature:
# bias: 30.0000
# variance: -44.4404
# skewness: -29.9736
# curtosis: -28.3791
# entropy: -6.3921
#
# Weight vector 115:
# Count (survival time): 20
# Weights by feature:
# bias: 31.0000
# variance: -42.7605
# skewness: -25.7668
# curtosis: -32.9189
# entropy: -8.7852
#
# Weight vector 116:
# Count (survival time): 23
# Weights by feature:
# bias: 32.0000
# variance: -45.9910
# skewness: -32.9803
# curtosis: -21.2756
# entropy: -9.7313
#
# Weight vector 117:
# Count (survival time): 49
# Weights by feature:
# bias: 31.0000
# variance: -45.3462
# skewness: -28.3741
# curtosis: -29.6226
# entropy: -7.0214
#
# Weight vector 118:
# Count (survival time): 35
# Weights by feature:
# bias: 32.0000
# variance: -43.6131
# skewness: -24.4197
# curtosis: -34.3638
# entropy: -9.5231
#
# Weight vector 119:
# Count (survival time): 5
# Weights by feature:
# bias: 31.0000
# variance: -42.8262
# skewness: -33.9860
# curtosis: -30.5771
# entropy: -2.0197
#
# Weight vector 120:
# Count (survival time): 122
# Weights by feature:
# bias: 32.0000
# variance: -41.3185
# skewness: -32.0264
# curtosis: -33.6355
# entropy: -2.1421
#
# Weight vector 121:
# Count (survival time): 21
# Weights by feature:
# bias: 33.0000
# variance: -38.9268
# skewness: -27.4699
# curtosis: -38.6243
# entropy: -5.0408
#
# Weight vector 122:
# Count (survival time): 27
# Weights by feature:
# bias: 34.0000
# variance: -42.5321
# skewness: -33.4439
# curtosis: -28.5327
# entropy: -5.8693
#
# Weight vector 123:
# Count (survival time): 27
# Weights by feature:
# bias: 33.0000
# variance: -42.3711
# skewness: -26.9815
# curtosis: -36.8900
# entropy: -4.3477
#
# Weight vector 124:
# Count (survival time): 12
# Weights by feature:
# bias: 34.0000
# variance: -46.0672
# skewness: -40.6594
# curtosis: -19.3105
# entropy: -6.9658
#
# Weight vector 125:
# Count (survival time): 1
# Weights by feature:
# bias: 35.0000
# variance: -45.1720
# skewness: -35.8856
# curtosis: -24.1536
# entropy: -12.5567
#
# Weight vector 126:
# Count (survival time): 113
# Weights by feature:
# bias: 34.0000
# variance: -45.6915
# skewness: -32.6223
# curtosis: -27.2431
# entropy: -11.5718
#
# Weight vector 127:
# Count (survival time): 1
# Weights by feature:
# bias: 33.0000
# variance: -46.0207
# skewness: -28.1671
# curtosis: -31.8149
# entropy: -10.5830
#
# Weight vector 128:
# Count (survival time): 38
# Weights by feature:
# bias: 34.0000
# variance: -43.9897
# skewness: -26.3151
# curtosis: -34.8270
# entropy: -10.5800
#
# Weight vector 129:
# Count (survival time): 52
# Weights by feature:
# bias: 35.0000
# variance: -41.9720
# skewness: -24.5169
# curtosis: -37.7851
# entropy: -10.3701
#
# Weight vector 130:
# Count (survival time): 84
# Weights by feature:
# bias: 36.0000
# variance: -43.8111
# skewness: -33.6052
# curtosis: -28.5435
# entropy: -10.4744
#
# Weight vector 131:
# Count (survival time): 152
# Weights by feature:
# bias: 37.0000
# variance: -42.3610
# skewness: -29.9985
# curtosis: -32.5992
# entropy: -12.0710
#
# Weight vector 132:
# Count (survival time): 6
# Weights by feature:
# bias: 36.0000
# variance: -42.6902
# skewness: -25.5433
# curtosis: -37.1710
# entropy: -11.0822
#
# Weight vector 133:
# Count (survival time): 38
# Weights by feature:
# bias: 37.0000
# variance: -44.4006
# skewness: -30.3213
# curtosis: -30.9601
# entropy: -10.6848
#
# Weight vector 134:
# Count (survival time): 49
# Weights by feature:
# bias: 36.0000
# variance: -44.9201
# skewness: -27.0580
# curtosis: -34.0496
# entropy: -9.6999
#
# Weight vector 135:
# Count (survival time): 17
# Weights by feature:
# bias: 35.0000
# variance: -45.4396
# skewness: -23.7947
# curtosis: -37.1391
# entropy: -8.7150
#
# Weight vector 136:
# Count (survival time): 23
# Weights by feature:
# bias: 36.0000
# variance: -48.6701
# skewness: -31.0082
# curtosis: -25.4958
# entropy: -9.6611
#
# Weight vector 137:
# Count (survival time): 84
# Weights by feature:
# bias: 35.0000
# variance: -48.0254
# skewness: -26.4020
# curtosis: -33.8428
# entropy: -6.9512
#
# Weight vector 138:
# Count (survival time): 5
# Weights by feature:
# bias: 34.0000
# variance: -47.2385
# skewness: -35.9683
# curtosis: -30.0561
# entropy: 0.5522
#
# Weight vector 139:
# Count (survival time): 82
# Weights by feature:
# bias: 35.0000
# variance: -45.7308
# skewness: -34.0087
# curtosis: -33.1145
# entropy: 0.4298
#
# Weight vector 140:
# Count (survival time): 38
# Weights by feature:
# bias: 36.0000
# variance: -44.9932
# skewness: -29.1562
# curtosis: -37.9131
# entropy: -5.2361
#
# Weight vector 141:
# Count (survival time): 2
# Weights by feature:
# bias: 37.0000
# variance: -49.3705
# skewness: -34.6729
# curtosis: -26.9741
# entropy: -5.6443
#
# Weight vector 142:
# Count (survival time): 53
# Weights by feature:
# bias: 38.0000
# variance: -46.9788
# skewness: -30.1164
# curtosis: -31.9629
# entropy: -8.5430
#
# Weight vector 143:
# Count (survival time): 22
# Weights by feature:
# bias: 37.0000
# variance: -47.4983
# skewness: -26.8531
# curtosis: -35.0524
# entropy: -7.5581
#
# Weight vector 144:
# Count (survival time): 12
# Weights by feature:
# bias: 38.0000
# variance: -51.1944
# skewness: -40.5310
# curtosis: -17.4729
# entropy: -10.1762
#
# Weight vector 145:
# Count (survival time): 1
# Weights by feature:
# bias: 39.0000
# variance: -50.2993
# skewness: -35.7572
# curtosis: -22.3160
# entropy: -15.7671
#
# Weight vector 146:
# Count (survival time): 113
# Weights by feature:
# bias: 38.0000
# variance: -50.8188
# skewness: -32.4939
# curtosis: -25.4055
# entropy: -14.7822
#
# Weight vector 147:
# Count (survival time): 1
# Weights by feature:
# bias: 37.0000
# variance: -51.1480
# skewness: -28.0387
# curtosis: -29.9773
# entropy: -13.7934
#
# Weight vector 148:
# Count (survival time): 38
# Weights by feature:
# bias: 38.0000
# variance: -49.1170
# skewness: -26.1867
# curtosis: -32.9894
# entropy: -13.7904
#
# Weight vector 149:
# Count (survival time): 55
# Weights by feature:
# bias: 39.0000
# variance: -47.0993
# skewness: -24.3885
# curtosis: -35.9475
# entropy: -13.5805
#
# Weight vector 150:
# Count (survival time): 81
# Weights by feature:
# bias: 38.0000
# variance: -46.3124
# skewness: -33.9548
# curtosis: -32.1608
# entropy: -6.0771
#
# Weight vector 151:
# Count (survival time): 61
# Weights by feature:
# bias: 39.0000
# variance: -44.8623
# skewness: -30.3481
# curtosis: -36.2165
# entropy: -7.6737
#
# Weight vector 152:
# Count (survival time): 13
# Weights by feature:
# bias: 40.0000
# variance: -48.2205
# skewness: -37.5885
# curtosis: -24.7746
# entropy: -8.2449
#
# Weight vector 153:
# Count (survival time): 78
# Weights by feature:
# bias: 41.0000
# variance: -46.7309
# skewness: -34.1597
# curtosis: -28.8055
# entropy: -9.6708
#
# Weight vector 154:
# Count (survival time): 44
# Weights by feature:
# bias: 40.0000
# variance: -47.0601
# skewness: -29.7045
# curtosis: -33.3773
# entropy: -8.6820
#
# Weight vector 155:
# Count (survival time): 13
# Weights by feature:
# bias: 39.0000
# variance: -47.5796
# skewness: -26.4412
# curtosis: -36.4668
# entropy: -7.6971
#
# Weight vector 156:
# Count (survival time): 8
# Weights by feature:
# bias: 40.0000
# variance: -50.7219
# skewness: -39.4777
# curtosis: -20.7895
# entropy: -8.3587
#
# Weight vector 157:
# Count (survival time): 25
# Weights by feature:
# bias: 39.0000
# variance: -51.6516
# skewness: -35.6806
# curtosis: -25.4324
# entropy: -8.0630
#
# Weight vector 158:
# Count (survival time): 3
# Weights by feature:
# bias: 40.0000
# variance: -49.9717
# skewness: -31.4738
# curtosis: -29.9722
# entropy: -10.4561
#
# Weight vector 159:
# Count (survival time): 124
# Weights by feature:
# bias: 39.0000
# variance: -50.4912
# skewness: -28.2105
# curtosis: -33.0617
# entropy: -9.4712
#
# Weight vector 160:
# Count (survival time): 5
# Weights by feature:
# bias: 38.0000
# variance: -49.7043
# skewness: -37.7768
# curtosis: -29.2750
# entropy: -1.9678
#
# Weight vector 161:
# Count (survival time): 82
# Weights by feature:
# bias: 39.0000
# variance: -48.1966
# skewness: -35.8172
# curtosis: -32.3334
# entropy: -2.0902
#
# Weight vector 162:
# Count (survival time): 40
# Weights by feature:
# bias: 40.0000
# variance: -47.4590
# skewness: -30.9647
# curtosis: -37.1320
# entropy: -7.7561
#
# Weight vector 163:
# Count (survival time): 11
# Weights by feature:
# bias: 41.0000
# variance: -45.0673
# skewness: -26.4082
# curtosis: -42.1208
# entropy: -10.6548
#
# Weight vector 164:
# Count (survival time): 37
# Weights by feature:
# bias: 42.0000
# variance: -48.8246
# skewness: -34.6998
# curtosis: -31.8176
# entropy: -10.2742
#
# Weight vector 165:
# Count (survival time): 27
# Weights by feature:
# bias: 41.0000
# variance: -48.6635
# skewness: -28.2374
# curtosis: -40.1749
# entropy: -8.7526
#
# Weight vector 166:
# Count (survival time): 12
# Weights by feature:
# bias: 42.0000
# variance: -52.3596
# skewness: -41.9153
# curtosis: -22.5954
# entropy: -11.3707
#
# Weight vector 167:
# Count (survival time): 1
# Weights by feature:
# bias: 43.0000
# variance: -51.4645
# skewness: -37.1415
# curtosis: -27.4385
# entropy: -16.9616
#
# Weight vector 168:
# Count (survival time): 113
# Weights by feature:
# bias: 42.0000
# variance: -51.9840
# skewness: -33.8782
# curtosis: -30.5280
# entropy: -15.9767
#
# Weight vector 169:
# Count (survival time): 1
# Weights by feature:
# bias: 41.0000
# variance: -52.3132
# skewness: -29.4230
# curtosis: -35.0998
# entropy: -14.9879
#
# Weight vector 170:
# Count (survival time): 93
# Weights by feature:
# bias: 42.0000
# variance: -50.2822
# skewness: -27.5710
# curtosis: -38.1119
# entropy: -14.9849
#
# Weight vector 171:
# Count (survival time): 81
# Weights by feature:
# bias: 41.0000
# variance: -49.4953
# skewness: -37.1373
# curtosis: -34.3252
# entropy: -7.4815
#
# Weight vector 172:
# Count (survival time): 27
# Weights by feature:
# bias: 42.0000
# variance: -48.0452
# skewness: -33.5306
# curtosis: -38.3809
# entropy: -9.0781
#
# Weight vector 173:
# Count (survival time): 2
# Weights by feature:
# bias: 43.0000
# variance: -45.8509
# skewness: -28.9803
# curtosis: -43.3569
# entropy: -11.8035
#
# Weight vector 174:
# Count (survival time): 45
# Weights by feature:
# bias: 44.0000
# variance: -49.8727
# skewness: -37.2843
# curtosis: -30.8019
# entropy: -13.3134
#
# Weight vector 175:
# Count (survival time): 78
# Weights by feature:
# bias: 45.0000
# variance: -48.3831
# skewness: -33.8555
# curtosis: -34.8328
# entropy: -14.7393
#
# Weight vector 176:
# Count (survival time): 44
# Weights by feature:
# bias: 44.0000
# variance: -48.7123
# skewness: -29.4003
# curtosis: -39.4046
# entropy: -13.7505
#
# Weight vector 177:
# Count (survival time): 13
# Weights by feature:
# bias: 43.0000
# variance: -49.2318
# skewness: -26.1370
# curtosis: -42.4941
# entropy: -12.7656
#
# Weight vector 178:
# Count (survival time): 8
# Weights by feature:
# bias: 44.0000
# variance: -52.3741
# skewness: -39.1735
# curtosis: -26.8168
# entropy: -13.4273
#
# Weight vector 179:
# Count (survival time): 25
# Weights by feature:
# bias: 43.0000
# variance: -53.3038
# skewness: -35.3764
# curtosis: -31.4597
# entropy: -13.1316
#
# Weight vector 180:
# Count (survival time): 3
# Weights by feature:
# bias: 44.0000
# variance: -51.6239
# skewness: -31.1696
# curtosis: -35.9995
# entropy: -15.5247
#
# Weight vector 181:
# Count (survival time): 17
# Weights by feature:
# bias: 43.0000
# variance: -52.1434
# skewness: -27.9063
# curtosis: -39.0890
# entropy: -14.5398
#
# Weight vector 182:
# Count (survival time): 23
# Weights by feature:
# bias: 44.0000
# variance: -55.3739
# skewness: -35.1198
# curtosis: -27.4457
# entropy: -15.4859
#
# Weight vector 183:
# Count (survival time): 84
# Weights by feature:
# bias: 43.0000
# variance: -54.7292
# skewness: -30.5136
# curtosis: -35.7927
# entropy: -12.7760
#
# Weight vector 184:
# Count (survival time): 5
# Weights by feature:
# bias: 42.0000
# variance: -53.9423
# skewness: -40.0799
# curtosis: -32.0060
# entropy: -5.2726
#
# Weight vector 185:
# Count (survival time): 122
# Weights by feature:
# bias: 43.0000
# variance: -52.4346
# skewness: -38.1203
# curtosis: -35.0644
# entropy: -5.3950
#
# Weight vector 186:
# Count (survival time): 53
# Weights by feature:
# bias: 44.0000
# variance: -50.0429
# skewness: -33.5638
# curtosis: -40.0532
# entropy: -8.2937
#
# Weight vector 187:
# Count (survival time): 22
# Weights by feature:
# bias: 43.0000
# variance: -50.5624
# skewness: -30.3005
# curtosis: -43.1427
# entropy: -7.3088
#
# Weight vector 188:
# Count (survival time): 12
# Weights by feature:
# bias: 44.0000
# variance: -54.2585
# skewness: -43.9784
# curtosis: -25.5632
# entropy: -9.9269
#
# Weight vector 189:
# Count (survival time): 1
# Weights by feature:
# bias: 45.0000
# variance: -53.3634
# skewness: -39.2046
# curtosis: -30.4063
# entropy: -15.5178
#
# Weight vector 190:
# Count (survival time): 113
# Weights by feature:
# bias: 44.0000
# variance: -53.8829
# skewness: -35.9413
# curtosis: -33.4958
# entropy: -14.5329
#
# Weight vector 191:
# Count (survival time): 1
# Weights by feature:
# bias: 43.0000
# variance: -54.2121
# skewness: -31.4861
# curtosis: -38.0676
# entropy: -13.5441
#
# Weight vector 192:
# Count (survival time): 93
# Weights by feature:
# bias: 44.0000
# variance: -52.1811
# skewness: -29.6341
# curtosis: -41.0797
# entropy: -13.5411
#
# Weight vector 193:
# Count (survival time): 81
# Weights by feature:
# bias: 43.0000
# variance: -51.3942
# skewness: -39.2004
# curtosis: -37.2930
# entropy: -6.0377
#
# Weight vector 194:
# Count (survival time): 27
# Weights by feature:
# bias: 44.0000
# variance: -49.9441
# skewness: -35.5937
# curtosis: -41.3487
# entropy: -7.6343
#
# Weight vector 195:
# Count (survival time): 2
# Weights by feature:
# bias: 45.0000
# variance: -47.7498
# skewness: -31.0434
# curtosis: -46.3247
# entropy: -10.3597
#
# Weight vector 196:
# Count (survival time): 45
# Weights by feature:
# bias: 46.0000
# variance: -51.7716
# skewness: -39.3474
# curtosis: -33.7697
# entropy: -11.8696
#
# Weight vector 197:
# Count (survival time): 78
# Weights by feature:
# bias: 47.0000
# variance: -50.2820
# skewness: -35.9186
# curtosis: -37.8006
# entropy: -13.2955
#
# Weight vector 198:
# Count (survival time): 44
# Weights by feature:
# bias: 46.0000
# variance: -50.6112
# skewness: -31.4634
# curtosis: -42.3724
# entropy: -12.3067
#
# Weight vector 199:
# Count (survival time): 13
# Weights by feature:
# bias: 45.0000
# variance: -51.1307
# skewness: -28.2001
# curtosis: -45.4619
# entropy: -11.3218
#
# Weight vector 200:
# Count (survival time): 8
# Weights by feature:
# bias: 46.0000
# variance: -54.2730
# skewness: -41.2366
# curtosis: -29.7846
# entropy: -11.9835
#
# Weight vector 201:
# Count (survival time): 25
# Weights by feature:
# bias: 45.0000
# variance: -55.2027
# skewness: -37.4395
# curtosis: -34.4275
# entropy: -11.6878
#
# Weight vector 202:
# Count (survival time): 3
# Weights by feature:
# bias: 46.0000
# variance: -53.5228
# skewness: -33.2327
# curtosis: -38.9673
# entropy: -14.0809
#
# Weight vector 203:
# Count (survival time): 17
# Weights by feature:
# bias: 45.0000
# variance: -54.0423
# skewness: -29.9694
# curtosis: -42.0568
# entropy: -13.0960
#
# Weight vector 204:
# Count (survival time): 23
# Weights by feature:
# bias: 46.0000
# variance: -57.2728
# skewness: -37.1829
# curtosis: -30.4135
# entropy: -14.0421
#
# Weight vector 205:
# Count (survival time): 84
# Weights by feature:
# bias: 45.0000
# variance: -56.6281
# skewness: -32.5767
# curtosis: -38.7605
# entropy: -11.3322
#
# Weight vector 206:
# Count (survival time): 5
# Weights by feature:
# bias: 44.0000
# variance: -55.8412
# skewness: -42.1430
# curtosis: -34.9738
# entropy: -3.8288
#
# Weight vector 207:
# Count (survival time): 122
# Weights by feature:
# bias: 45.0000
# variance: -54.3335
# skewness: -40.1834
# curtosis: -38.0322
# entropy: -3.9512
#
# Weight vector 208:
# Count (survival time): 32
# Weights by feature:
# bias: 46.0000
# variance: -51.9418
# skewness: -35.6269
# curtosis: -43.0210
# entropy: -6.8499
#
# Weight vector 209:
# Count (survival time): 16
# Weights by feature:
# bias: 47.0000
# variance: -55.0284
# skewness: -42.2631
# curtosis: -32.4805
# entropy: -7.7417
#
# Weight vector 210:
# Count (survival time): 5
# Weights by feature:
# bias: 46.0000
# variance: -54.8673
# skewness: -35.8007
# curtosis: -40.8378
# entropy: -6.2201
#
# Weight vector 211:
# Count (survival time): 22
# Weights by feature:
# bias: 45.0000
# variance: -55.3868
# skewness: -32.5374
# curtosis: -43.9273
# entropy: -5.2352
#
# Weight vector 212:
# Count (survival time): 12
# Weights by feature:
# bias: 46.0000
# variance: -59.0829
# skewness: -46.2153
# curtosis: -26.3478
# entropy: -7.8533
#
# Weight vector 213:
# Count (survival time): 1
# Weights by feature:
# bias: 47.0000
# variance: -58.1878
# skewness: -41.4415
# curtosis: -31.1909
# entropy: -13.4442
#
# Weight vector 214:
# Count (survival time): 113
# Weights by feature:
# bias: 46.0000
# variance: -58.7072
# skewness: -38.1782
# curtosis: -34.2804
# entropy: -12.4593
#
# Weight vector 215:
# Count (survival time): 1
# Weights by feature:
# bias: 45.0000
# variance: -59.0364
# skewness: -33.7230
# curtosis: -38.8522
# entropy: -11.4705
#
# Weight vector 216:
# Count (survival time): 38
# Weights by feature:
# bias: 46.0000
# variance: -57.0054
# skewness: -31.8710
# curtosis: -41.8643
# entropy: -11.4675
#
# Weight vector 217:
# Count (survival time): 55
# Weights by feature:
# bias: 47.0000
# variance: -54.9877
# skewness: -30.0728
# curtosis: -44.8224
# entropy: -11.2576
#
# Weight vector 218:
# Count (survival time): 81
# Weights by feature:
# bias: 46.0000
# variance: -54.2008
# skewness: -39.6391
# curtosis: -41.0357
# entropy: -3.7542
#
# Weight vector 219:
# Count (survival time): 34
# Weights by feature:
# bias: 47.0000
# variance: -52.7507
# skewness: -36.0324
# curtosis: -45.0914
# entropy: -5.3508
#
# Weight vector 220:
# Count (survival time): 1
# Weights by feature:
# bias: 48.0000
# variance: -56.5710
# skewness: -49.0875
# curtosis: -28.1331
# entropy: -7.6560
#
# Weight vector 221:
# Count (survival time): 39
# Weights by feature:
# bias: 49.0000
# variance: -62.0518
# skewness: -40.9056
# curtosis: -27.8550
# entropy: -12.6883
#
# Weight vector 222:
# Count (survival time): 78
# Weights by feature:
# bias: 50.0000
# variance: -60.5622
# skewness: -37.4768
# curtosis: -31.8859
# entropy: -14.1142
#
# Weight vector 223:
# Count (survival time): 44
# Weights by feature:
# bias: 49.0000
# variance: -60.8915
# skewness: -33.0216
# curtosis: -36.4577
# entropy: -13.1254
#
# Weight vector 224:
# Count (survival time): 49
# Weights by feature:
# bias: 48.0000
# variance: -61.4110
# skewness: -29.7583
# curtosis: -39.5472
# entropy: -12.1405
#
# Weight vector 225:
# Count (survival time): 17
# Weights by feature:
# bias: 47.0000
# variance: -61.9305
# skewness: -26.4950
# curtosis: -42.6367
# entropy: -11.1556
#
# Weight vector 226:
# Count (survival time): 23
# Weights by feature:
# bias: 48.0000
# variance: -65.1610
# skewness: -33.7085
# curtosis: -30.9934
# entropy: -12.1017
#
# Weight vector 227:
# Count (survival time): 84
# Weights by feature:
# bias: 47.0000
# variance: -64.5163
# skewness: -29.1023
# curtosis: -39.3404
# entropy: -9.3918
#
# Weight vector 228:
# Count (survival time): 5
# Weights by feature:
# bias: 46.0000
# variance: -63.7294
# skewness: -38.6686
# curtosis: -35.5537
# entropy: -1.8884
#
# Weight vector 229:
# Count (survival time): 122
# Weights by feature:
# bias: 47.0000
# variance: -62.2217
# skewness: -36.7090
# curtosis: -38.6121
# entropy: -2.0109
#
# Weight vector 230:
# Count (survival time): 32
# Weights by feature:
# bias: 48.0000
# variance: -59.8300
# skewness: -32.1525
# curtosis: -43.6009
# entropy: -4.9096
#
# Weight vector 231:
# Count (survival time): 16
# Weights by feature:
# bias: 49.0000
# variance: -62.9166
# skewness: -38.7887
# curtosis: -33.0604
# entropy: -5.8014
#
# Weight vector 232:
# Count (survival time): 154
# Weights by feature:
# bias: 48.0000
# variance: -62.7555
# skewness: -32.3263
# curtosis: -41.4177
# entropy: -4.2798
#
# Weight vector 233:
# Count (survival time): 15
# Weights by feature:
# bias: 49.0000
# variance: -60.7245
# skewness: -30.4743
# curtosis: -44.4298
# entropy: -4.2768
#
# Weight vector 234:
# Count (survival time): 23
# Weights by feature:
# bias: 50.0000
# variance: -64.7418
# skewness: -38.7866
# curtosis: -31.9751
# entropy: -5.7143
#
# Weight vector 235:
# Count (survival time): 136
# Weights by feature:
# bias: 51.0000
# variance: -62.7241
# skewness: -36.9884
# curtosis: -34.9332
# entropy: -5.5044
#
# Weight vector 236:
# Count (survival time): 27
# Weights by feature:
# bias: 52.0000
# variance: -61.2740
# skewness: -33.3817
# curtosis: -38.9889
# entropy: -7.1010
#
# Weight vector 237:
# Count (survival time): 2
# Weights by feature:
# bias: 53.0000
# variance: -59.0797
# skewness: -28.8314
# curtosis: -43.9649
# entropy: -9.8264
#
# Weight vector 238:
# Count (survival time): 45
# Weights by feature:
# bias: 54.0000
# variance: -63.1015
# skewness: -37.1354
# curtosis: -31.4099
# entropy: -11.3363
#
# Weight vector 239:
# Count (survival time): 78
# Weights by feature:
# bias: 55.0000
# variance: -61.6119
# skewness: -33.7066
# curtosis: -35.4408
# entropy: -12.7622
#
# Weight vector 240:
# Count (survival time): 44
# Weights by feature:
# bias: 54.0000
# variance: -61.9411
# skewness: -29.2514
# curtosis: -40.0126
# entropy: -11.7734
#
# Weight vector 241:
# Count (survival time): 13
# Weights by feature:
# bias: 53.0000
# variance: -62.4606
# skewness: -25.9881
# curtosis: -43.1021
# entropy: -10.7885
#
# Weight vector 242:
# Count (survival time): 8
# Weights by feature:
# bias: 54.0000
# variance: -65.6029
# skewness: -39.0246
# curtosis: -27.4248
# entropy: -11.4501
#
# Weight vector 243:
# Count (survival time): 25
# Weights by feature:
# bias: 53.0000
# variance: -66.5326
# skewness: -35.2275
# curtosis: -32.0677
# entropy: -11.1544
#
# Weight vector 244:
# Count (survival time): 3
# Weights by feature:
# bias: 54.0000
# variance: -64.8527
# skewness: -31.0207
# curtosis: -36.6075
# entropy: -13.5475
#
# Weight vector 245:
# Count (survival time): 124
# Weights by feature:
# bias: 53.0000
# variance: -65.3722
# skewness: -27.7574
# curtosis: -39.6970
# entropy: -12.5626
#
# Weight vector 246:
# Count (survival time): 5
# Weights by feature:
# bias: 52.0000
# variance: -64.5853
# skewness: -37.3237
# curtosis: -35.9103
# entropy: -5.0592
#
# Weight vector 247:
# Count (survival time): 122
# Weights by feature:
# bias: 53.0000
# variance: -63.0776
# skewness: -35.3641
# curtosis: -38.9687
# entropy: -5.1817
#
# Weight vector 248:
# Count (survival time): 32
# Weights by feature:
# bias: 54.0000
# variance: -60.6859
# skewness: -30.8076
# curtosis: -43.9575
# entropy: -8.0804
#
# Weight vector 249:
# Count (survival time): 16
# Weights by feature:
# bias: 55.0000
# variance: -63.7725
# skewness: -37.4438
# curtosis: -33.4170
# entropy: -8.9722
#
# Weight vector 250:
# Count (survival time): 5
# Weights by feature:
# bias: 54.0000
# variance: -63.6114
# skewness: -30.9814
# curtosis: -41.7743
# entropy: -7.4506
#
# Weight vector 251:
# Count (survival time): 22
# Weights by feature:
# bias: 53.0000
# variance: -64.1309
# skewness: -27.7181
# curtosis: -44.8638
# entropy: -6.4657
#
# Weight vector 252:
# Count (survival time): 12
# Weights by feature:
# bias: 54.0000
# variance: -67.8270
# skewness: -41.3960
# curtosis: -27.2843
# entropy: -9.0838
#
# Weight vector 253:
# Count (survival time): 1
# Weights by feature:
# bias: 55.0000
# variance: -66.9319
# skewness: -36.6222
# curtosis: -32.1274
# entropy: -14.6747
#
# Weight vector 254:
# Count (survival time): 31
# Weights by feature:
# bias: 54.0000
# variance: -67.4514
# skewness: -33.3589
# curtosis: -35.2169
# entropy: -13.6898
#
# Weight vector 255:
# Count (survival time): 82
# Weights by feature:
# bias: 53.0000
# variance: -65.5930
# skewness: -41.2449
# curtosis: -33.5526
# entropy: -11.8514
#
# Weight vector 256:
# Count (survival time): 1
# Weights by feature:
# bias: 52.0000
# variance: -65.9222
# skewness: -36.7897
# curtosis: -38.1244
# entropy: -10.8626
#
# Weight vector 257:
# Count (survival time): 38
# Weights by feature:
# bias: 53.0000
# variance: -63.8912
# skewness: -34.9377
# curtosis: -41.1365
# entropy: -10.8596
#
# Weight vector 258:
# Count (survival time): 55
# Weights by feature:
# bias: 54.0000
# variance: -61.8735
# skewness: -33.1395
# curtosis: -44.0946
# entropy: -10.6497
#
# Weight vector 259:
# Count (survival time): 36
# Weights by feature:
# bias: 53.0000
# variance: -61.0866
# skewness: -42.7058
# curtosis: -40.3079
# entropy: -3.1463
